# %% [markdown]
# # Prepare Data (Load&merge)

# %%
# !pip install numpy==1.15.1

# %%
# !pip install pyarrow==0.15.1
# Out:
# ...
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import pyarrow

# %%
data = pd.read_parquet('s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00001-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet')

# %%
data.head(12)
# Out:
#    data_type                vin polk_con_num               dealer_name  \
# 0          N  1FTEW1E52JFD12608      0030045           PERMIAN LINCOLN
# 1          N  1GCPYFED2KZ403868      0163534      EL DORADO MOTORS INC
# 2          N  1FTEW1EP7KKC21120      0001254       RICH FORD SALES INC
# 3          N  1C4PJMLB3KD473144      0023019  MARKS CASA CHRYSLER JEEP
# 4          N  1GNEVGKW5LJ102952      0310485           AMIGO CHEVROLET
# 5          N  1GT49REY4LF125014      0029004           PITRE BUICK GMC
# 6          N  2FMHK6C88KBA18289      0265177               MELLOY FORD
# 7          N  1FTMF1CB8KKC49835      0265177               MELLOY FORD
# 8          N  1FMCU0HD4KUB60737      0265177               MELLOY FORD
# 9          N  1FTER4FH4KLA59456      0001254       RICH FORD SALES INC
# 10         N  2FMPK4K93KBC36201      0001254       RICH FORD SALES INC
# 11         N  4T1B11HK3KU822669      0190920     STEVINSON TOYOTA EAST
#
# ...

# %%
appended_data = []
for x in list(range(0, 129)):
    if x < 10:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-0000" + str(x) + "-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet"
        print(filename)
    elif 10<=x<100:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-000" + str(x) + "-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet"
    else:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00" + str(x) + "-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet"
        print(filename)
    data = pd.read_parquet(filename)
    print(data.shape)
    # store DataFrame in list
    appended_data.append(data)
# see pd.concat documentation for more info
polk_08 = pd.concat(appended_data)
# Out:
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00000-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (12334, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00001-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (11777, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00002-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (12160, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00003-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (12072, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00004-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (11658, 48)
# ...

# %%
polk_08.shape
# Out:
# (1482819, 48)

# %%
polk_08.columns
# Out:
# Index(['data_type', 'vin', 'polk_con_num', 'dealer_name', 'dealer_address',
#        'dealer_town', 'dealer_state', 'dealer_zip', 'dealer_dma',
#        'dealer_fran_ind', 'vin_year_model', 'segment', 'make', 'model',
#        'series', 'sub_series', 'vehicle_type', 'body_style', 'cylinders',
#        'drive_type', 'doors', 'fuel_type', 'orgin', 'gvw', 'bed_size',
#        'cab_size', 'turbo', 'financial_inst', 'veh_mfg_base_list_price',
#        'corporation', 'reg_dma', 'reg_state', 'reg_county', 'reg_zip',
#        'reg_type', 'purchase_lease', 'report_year_month', 'transaction_date',
#        'mileage', 'trans_price', 'age', 'income', 'gender', 'ethnic_group',
#        'sub_ethnic_group', 'language', 'reg_type_code', 'new_count'],
#       dtype='object')

# %%
len(polk_08.polk_con_num.unique())
# Out:
# 19100

# %%
len(polk_08.vin.unique())
# Out:
# 1328680

# %%
new=polk_08.drop_duplicates() 
new.shape
# Out:
# (1482819, 48)

# %%
appended_data = []
for x in list(range(0, 129)):
    if x < 10:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-0000" + str(x) + "-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet"
        print(filename)
    elif 10<=x<100:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-000" + str(x) + "-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet"
    else:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00" + str(x) + "-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet"
        print(filename)
    data = pd.read_parquet(filename)
    print(data.shape)
    # store DataFrame in list
    appended_data.append(data)
# see pd.concat documentation for more info
polk_08 = pd.concat(appended_data)
# Out:
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00000-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (12334, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00001-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (11777, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00002-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (12160, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00003-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (12072, 48)
# s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201908/part-00004-b9361f72-f006-4fbe-85ce-6784daef2629-c000.snappy.parquet
# (11658, 48)
# ...

# %%
appended_data = []
for x in list(range(0, 129)):
    if x < 10:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201909/part-0000" + str(x) + "-84ff5662-8cd9-4b28-9625-fcd31c0155a7-c000.snappy.parquet"
    elif 10<=x<100:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201909/part-000" + str(x) + "-84ff5662-8cd9-4b28-9625-fcd31c0155a7-c000.snappy.parquet"
    else:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201909/part-00" + str(x) + "-84ff5662-8cd9-4b28-9625-fcd31c0155a7-c000.snappy.parquet"
        print(filename)
    data = pd.read_parquet(filename)
    print(data.shape)
    # store DataFrame in list
    appended_data.append(data)
# see pd.concat documentation for more info
polk_09 = pd.concat(appended_data)
# Out:
# (11496, 48)
# (10430, 48)
# (12082, 48)
# (12131, 48)
# (12247, 48)
# (12117, 48)
# (10747, 48)
# (11052, 48)
# (11356, 48)
# (10913, 48)
# (11157, 48)
# (11190, 48)
# (11974, 48)
# (11718, 48)
# (11015, 48)
# (9681, 48)
# (10219, 48)
# (12631, 48)
# (12006, 48)
# (12071, 48)
# (11307, 48)
# (10856, 48)
# (10209, 48)
# (10967, 48)
# (11092, 48)
# (10580, 48)
# (10525, 48)
# (10699, 48)
# (10521, 48)
# (11480, 48)
# (13567, 48)
# (12528, 48)
# (11042, 48)
# (10603, 48)
# (10654, 48)
# (11317, 48)
# (6675, 48)
# (10843, 48)
# (10699, 48)
# (10852, 48)
# (10216, 48)
# (9854, 48)
# (10267, 48)
# (10846, 48)
# (11525, 48)
# (11330, 48)
# (11215, 48)
# (11345, 48)
# (10880, 48)
# (11249, 48)
# (10930, 48)
# (11669, 48)
# (11039, 48)
# (11979, 48)
# (12519, 48)
# (9062, 48)
# (10076, 48)
# (9779, 48)
# (9941, 48)
# (10965, 48)
# (10094, 48)
# (9695, 48)
# (11415, 48)
# (11362, 48)
# (10286, 48)
# (10059, 48)
# (10096, 48)
# (11052, 48)
# (11079, 48)
# (11706, 48)
# (10792, 48)
# ...

# %%
appended_data = []
for x in list(range(0, 129)):
    if x < 10:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201910/part-0000" + str(x) + "-1f817633-99cd-4db4-9389-2571dda5de85-c000.snappy.parquet"
    elif 10<=x<100:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201910/part-000" + str(x) + "-1f817633-99cd-4db4-9389-2571dda5de85-c000.snappy.parquet"
    else:
        filename = "s3://cads-emory-data/data/parquet/polk_ihs_markit_registrations/new/ingest_month=201910/part-00" + str(x) + "-1f817633-99cd-4db4-9389-2571dda5de85-c000.snappy.parquet"
        print(filename)
    data = pd.read_parquet(filename)
    print(data.shape)
    # store DataFrame in list
    appended_data.append(data)
# see pd.concat documentation for more info
polk_10 = pd.concat(appended_data)
# Out:
# (10821, 48)
# (9924, 48)
# (10296, 48)
# (10467, 48)
# (10400, 48)
# (13643, 48)
# (9865, 48)
# (9533, 48)
# (11341, 48)
# (10015, 48)
# (10108, 48)
# (10208, 48)
# (10829, 48)
# (10534, 48)
# (9803, 48)
# (9279, 48)
# (8884, 48)
# (12095, 48)
# (11305, 48)
# (11511, 48)
# (10712, 48)
# (10327, 48)
# (10559, 48)
# (10316, 48)
# (10919, 48)
# (10872, 48)
# (10736, 48)
# (10966, 48)
# (10754, 48)
# (10765, 48)
# (9574, 48)
# (9405, 48)
# (10815, 48)
# (10207, 48)
# (10491, 48)
# (10724, 48)
# (5664, 48)
# (10309, 48)
# (11316, 48)
# (10379, 48)
# (10224, 48)
# (9987, 48)
# (11240, 48)
# (10351, 48)
# (11945, 48)
# (12798, 48)
# (12978, 48)
# (12238, 48)
# (9828, 48)
# (10566, 48)
# (10674, 48)
# (11688, 48)
# (9875, 48)
# (11302, 48)
# (11046, 48)
# (9410, 48)
# (9978, 48)
# (9832, 48)
# (10017, 48)
# (10470, 48)
# (10429, 48)
# (9772, 48)
# (10973, 48)
# (10873, 48)
# (10942, 48)
# (11242, 48)
# (11291, 48)
# (10859, 48)
# (10282, 48)
# (10176, 48)
# (9781, 48)
# (10278, 48)
# ...

# %%
pdList = [polk_08,polk_09,polk_10]  
polk_data = pd.concat(pdList)

# %%
polk_data.shape
# Out:
# (4219738, 48)

# %% [markdown]
# # Clean Data

# %%
new=polk_data.drop_duplicates() 
new.shape
# Out:
# (4219738, 48)

# %% [markdown]
# ## unique vin&transaction_date

# %%
count_series = polk_data.groupby(['vin', 'transaction_date']).size()
new_df = count_series.to_frame(name = 'size').reset_index()
new_df.sort_values(by=['size'],ascending=False)  # size is the count of instances
# Out:
#                        vin transaction_date  size
# 2528591        5N1AT2MV*KC         20190831   366
# 2966874        7FARW2H5*KE         20190831   282
# 1468545        2HKRW2H5*KH         20190831   268
# 3176847        JN8AT2MV*KW         20190831   257
# 2117434        3VV2B7AX*KM         20190831   248
# 169154         1C4RJFBG*KC         20190930   242
# 2555363        5N1AZ2MS*KN         20190831   230
# 2528620        5N1AT2MV*KC         20190930   218
# 3176875        JN8AT2MV*KW         20190930   213
# 1609517        3C4NJDBB*KT         20190930   194
# 1434868        2HGFC2F6*KH         20190831   186
# 1475870        2HKRW2H8*KH         20190831   183
# 2008010        3N1AB7AP*KY         20190831   182
# 2973159        7FARW2H8*KE         20190831   182
# 117074         1C4PJMDX*KD         20190903   179
# 2404611        5FNYF6H5*KB         20190831   177
# 169127         1C4RJFBG*KC         20190903   171
# 2684025        5TDJZRFH*KS         20190930   168
# ...

# %%
pcar=new_df[new_df["size"]>1]
pcar['vin'].apply(len)
# Out:
# 2          11
# 3          11
# 4          11
# 9          11
# 10         11
# 11         11
# 12         11
# 13         11
# 14         11
# 16         11
# 17         11
# 18         11
# 22         11
# 23         11
# 24         11
# 25         11
# 26         11
# 28         11
# 29         11
# 30         11
# 31         11
# 32         11
# 35         11
# 37         11
# 39         11
# 40         11
# 41         11
# 42         11
# 45         11
# 46         11
#            ..
# 3890928    11
# 3890929    11
# 3890932    11
# 3890933    11
# 3890934    11
# 3890935    11
# 3890937    11
# 3892770    11
# 3892774    11
# 3892779    11
# 3892783    11
# 3892796    11
# 3893381    11
# 3893468    11
# 3893714    11
# 3893906    11
# 3894342    11
# 3894349    11
# 3894353    11
# 3894357    11
# 3894366    11
# 3894368    11
# 3894564    11
# 3894567    11
# 3894660    11
# 3894663    11
# 3894664    11
# 3895016    11
# 3895153    11
# 3895154    11
# ...

# %%
a = polk_data.vin.value_counts()
import numpy as np
res = list(zip(*np.unique(a, return_counts=True)))
res
# Out:
# [(1, 3781407),
#  (2, 486),
#  (3, 336),
#  (4, 260),
#  (5, 187),
#  (6, 142),
#  (7, 119),
#  (8, 109),
#  (9, 101),
#  (10, 88),
#  (11, 71),
#  (12, 67),
#  (13, 65),
#  (14, 59),
#  (15, 49),
#  (16, 53),
#  (17, 37),
#  (18, 34),
#  (19, 47),
#  (20, 31),
#  (21, 39),
#  (22, 36),
#  (23, 35),
#  (24, 22),
#  (25, 26),
#  (26, 36),
#  (27, 29),
#  (28, 30),
#  (29, 21),
#  (30, 25),
#  (31, 23),
#  (32, 20),
#  (33, 20),
#  (34, 15),
#  (35, 21),
#  (36, 15),
#  (37, 19),
#  (38, 15),
#  (39, 16),
#  (40, 19),
#  (41, 15),
#  (42, 16),
#  (43, 17),
#  (44, 20),
#  (45, 12),
#  (46, 12),
#  (47, 12),
#  (48, 15),
#  (49, 7),
#  (50, 4),
#  (51, 14),
#  (52, 15),
#  (53, 6),
#  (54, 9),
#  (55, 7),
#  (56, 5),
#  (57, 11),
#  (58, 12),
#  (59, 9),
#  (60, 13),
#  (61, 18),
#  (62, 16),
#  (63, 11),
#  (64, 13),
#  (65, 15),
#  (66, 5),
#  (67, 7),
#  (68, 9),
#  (69, 6),
#  (70, 8),
#  (71, 6),
#  (72, 4),
#  (73, 9),
#  (74, 9),
#  (75, 14),
#  (76, 5),
#  (77, 4),
#  (78, 8),
# ...

# %%
print (polk_data[(polk_data['vin']=='5N1AT2MV*KC') & (polk_data['transaction_date']=='20190831')&(polk_data['dealer_name']=='DESTINATION NISSAN')])
# Out:
#       data_type          vin polk_con_num         dealer_name  \
# 3159          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 5200          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 5245          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 5246          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 5252          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 5884          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 7133          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 7168          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 8113          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 8515          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 8988          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 9394          N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 10210         N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# 11009         N  5N1AT2MV*KC      0009510  DESTINATION NISSAN
# ...

# %% [markdown]
# ## clean data: polk_data.vin.str.len() == 17

# %%
polk_data_clean=polk_data[polk_data.vin.str.len() == 17]

# %%
polk_data_clean.head(5)
# Out:
#   data_type                vin polk_con_num                   dealer_name  \
# 0         N  2HKRW5H34KH413305      0168076   JOHN EAGLE HONDA OF HOUSTON
# 1         N  1FT7W2BT3KEF01065      0187122                   VERNON FORD
# 2         N  1FT7W2B66KEF39478      0264682                JIM BASS MAZDA
# 3         N  1FT8W3BT8KEF88536      0000903        LAWRENCE HALL FORD INC
# 4         N  1GCRWAEF2KZ185997      0000525  BAILEY TOLIVER CHEVROLET LLP
#
#                dealer_address dealer_town dealer_state dealer_zip  \
# 0        18787 NORTHWEST  FWY     HOUSTON           TX      77065
# 1          2803 WILBARGER  ST      VERNON           TX      76384
# 2  4032 W HOUSTON HARTE  EXPY  SAN ANGELO           TX      76901
# 3        2016 COMMERCIAL  AVE       ANSON           TX      79501
# 4        578 US HIGHWAY 277 S     HASKELL           TX      79521
#
#                dealer_dma dealer_fran_ind  ... mileage trans_price  \
# ...

# %%
polk_data.vin.str.len().unique()
# Out:
# array([17, 11])

# %%
polk_data_clean.vin.str.len().unique()
# Out:
# array([17])

# %%
polk_data_clean.shape # 378万
polk_data.shape # 9.5%
# Out:
# (4219738, 48)

# %%
count_series = polk_data_clean.groupby(['vin', 'transaction_date']).size()
new_df = count_series.to_frame(name = 'size').reset_index()
new_df.sort_values(by=['size'],ascending=False)  # size is the count of instances
# Out:
#                        vin transaction_date  size
# 0        19UDE2F30KA000840         20190318     1
# 2520205  5NMS2CAD2LH158172         20191007     1
# 2520207  5NMS2CAD2LH158236         20191007     1
# 2520208  5NMS2CAD2LH158284         20191014     1
# 2520209  5NMS2CAD2LH158303         20191007     1
# 2520210  5NMS2CAD2LH158348         20191014     1
# 2520211  5NMS2CAD2LH158396         20191003     1
# 2520212  5NMS2CAD2LH158477         20190923     1
# 2520213  5NMS2CAD2LH158558         20190924     1
# 2520214  5NMS2CAD2LH158575         20190925     1
# 2520215  5NMS2CAD2LH158589         20190924     1
# 2520216  5NMS2CAD2LH158608         20191029     1
# 2520217  5NMS2CAD2LH158771         20190924     1
# 2520218  5NMS2CAD2LH158785         20191025     1
# 2520219  5NMS2CAD2LH158902         20191011     1
# 2520220  5NMS2CAD2LH159144         20191002     1
# 2520221  5NMS2CAD2LH159306         20191014     1
# 2520222  5NMS2CAD2LH159757         20191015     1
# ...

# %%
count_series = polk_data_clean.groupby(['vin', 'polk_con_num']).size()
new_df = count_series.to_frame(name = 'size').reset_index()

# %%
new_df['size'].unique()
# Out:
# array([1])

# %%
count_series = polk_data_clean.groupby(['vin']).size()
new_df = count_series.to_frame(name = 'size').reset_index()

# %%
new_df['size'].unique()
# Out:
# array([1])

# %% [markdown]
# #

# %%
polk_data_clean=pd.read_csv("polk_data_clean.csv")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Important Variable Exploration

# %%
polk_data_clean.columns
# Out:
# Index(['data_type', 'vin', 'polk_con_num', 'dealer_name', 'dealer_address',
#        'dealer_town', 'dealer_state', 'dealer_zip', 'dealer_dma',
#        'dealer_fran_ind', 'vin_year_model', 'segment', 'make', 'model',
#        'series', 'sub_series', 'vehicle_type', 'body_style', 'cylinders',
#        'drive_type', 'doors', 'fuel_type', 'orgin', 'gvw', 'bed_size',
#        'cab_size', 'turbo', 'financial_inst', 'veh_mfg_base_list_price',
#        'corporation', 'reg_dma', 'reg_state', 'reg_county', 'reg_zip',
#        'reg_type', 'purchase_lease', 'report_year_month', 'transaction_date',
#        'mileage', 'trans_price', 'age', 'income', 'gender', 'ethnic_group',
#        'sub_ethnic_group', 'language', 'reg_type_code', 'new_count'],
#       dtype='object')

# %% [markdown]
# ### vin_year_model

# %%
polk_data_clean['vin_year_model'].unique()
# Out:
# array(['2019', '2020', '2018', '2017'], dtype=object)

# %% [markdown]
# ### model

# %%
polk_data_clean['model'].unique()
# Out:
# array(['CR-V', 'F SERIES', 'SILVERADO', 'SIENNA', 'ATLAS', 'RAV4',
#        'PILOT', 'CIVIC', 'ECOSPORT', 'OPTIMA', 'ROGUE SPORT', 'OUTLANDER',
#        'CHEROKEE', 'RAM', 'DURANGO', 'CHARGER', 'WRANGLER', 'SIERRA',
#        'TAHOE', 'CHALLENGER', 'EDGE', 'ESCAPE', 'EXPLORER', 'KICKS',
#        'MALIBU', 'TUNDRA', 'EXPEDITION', 'HIGHLANDER', 'FORTE',
#        'YUKON DENALI', 'ALTIMA', 'EXPRESS', 'SUBURBAN', 'WRX', 'MAXIMA',
#        'BLAZER', 'ENCLAVE', 'EQUINOX', 'GRAND CHEROKEE', 'JOURNEY', 'LX',
#        'RIO', 'SOUL', 'RANGER', 'TRAVERSE', 'ACADIA', 'YUKON XL',
#        'FRONTIER /XE', 'CAMRY', 'RENEGADE', 'PALISADE', 'GTI', 'JETTA',
#        'GLA', 'KONA', 'FUSION', 'FIT', 'SPORTAGE', 'ESCALADE', 'ENCORE',
#        'CORVETTE', 'TACOMA', 'MURANO', 'FIESTA', 'TUCSON', 'RX',
#        'COMPASS', 'SONATA', 'XT5', 'YUKON', 'FORESTER', 'COROLLA',
#        'CAMARO', 'PACIFICA', 'XC90', 'X3', 'ELANTRA SEDAN', 'CONTINENTAL',
#        '300', 'BEETLE', 'TRANSIT VAN', 'CX-5', '4 RUNNER',
# ...

# %% [markdown]
# ### make

# %%
make=polk_data_clean['make'].unique()
# Out:
# numpy.ndarray

# %%
make.sort(axis=-1, kind='quicksort', order=None)

# %%
print (make)
# Out:
# ['ACURA' 'ALFA ROMEO' 'ASTON MARTIN' 'AUDI' 'BENTLEY' 'BMW' 'BUGATTI'
#  'BUICK' 'CADILLAC' 'CHEVROLET' 'CHRYSLER' 'DODGE' 'FERRARI' 'FIAT' 'FORD'
#  'FREIGHTLINER' 'GEM' 'GENESIS' 'GMC' 'HONDA' 'HYUNDAI' 'INFINITI' 'ISUZU'
#  'JAGUAR' 'JEEP' 'KARMA' 'KIA' 'LAMBORGHINI' 'LAND ROVER' 'LEXUS'
#  'LINCOLN' 'LOTUS' 'MASERATI' 'MAZDA' 'MCLAREN' 'MERCEDES-BENZ' 'MINI'
#  'MITSUBISHI' 'MITSUBISHI FUSO' 'NISSAN' 'PORSCHE' 'RAM' 'ROLLS ROYCE'
#  'SMARTCAR' 'SUBARU' 'TESLA' 'TOYOTA' 'VOLKSWAGEN' 'VOLVO']

# %% [markdown]
# ### mileage

# %%
polk_data_clean['mileage'].max()
# Out:
# 89773.0

# %%
polk_data_clean['mileage'].min()
# Out:
# 1.0

# %%
mileage=polk_data_clean['mileage'].unique()
mileage.sort(axis=-1, kind='quicksort', order=None)
print (mileage)
# Out:
# [1.0000e+00 2.0000e+00 3.0000e+00 ... 8.9311e+04 8.9773e+04        nan]

# %% [markdown]
# ### date

# %%
type(polk_data_clean)
# Out:
# pandas.core.frame.DataFrame

# %%
polk_data_clean['transaction_date'].describe()
# Out:
# count    3.780323e+06
# mean     2.019082e+07
# std      1.453628e+03
# min      1.919102e+07
# 25%      2.019082e+07
# 50%      2.019091e+07
# 75%      2.019100e+07
# max      2.019110e+07
# Name: transaction_date, dtype: float64

# %%
polk_data_clean['transaction_date']=pd.to_datetime(polk_data_clean['transaction_date'], format='%Y%m%d', errors='coerce')

# %%
polk_data_clean['transaction_date'].describe()
# Out:
# count                 3780323
# unique                    905
# top       2019-09-30 00:00:00
# freq                   133130
# first     1919-10-18 00:00:00
# last      2019-11-02 00:00:00
# Name: transaction_date, dtype: object

# %%
polk_data_clean=polk_data_clean.sort_values(by=['transaction_date'])

# %%
polk_data_clean['transaction_date']
# Out:
# 1824095   1919-10-18
# 3508429   1919-11-13
# 3114415   1965-08-10
# 740770    1970-04-06
# 743152    1970-04-15
# 795790    1979-08-31
# 527134    1990-02-16
# 481487    1990-07-22
# 2082785   1999-09-02
# 830643    1999-09-04
# 2645681   1999-10-30
# 2080529   1999-11-30
# 7887      1999-12-31
# 1332442   1999-12-31
# 1334230   1999-12-31
# 2576438   1999-12-31
# 862038    1999-12-31
# 1333117   1999-12-31
# 1332862   1999-12-31
# 4890      1999-12-31
# 1334235   1999-12-31
# 1332832   1999-12-31
# 1330615   1999-12-31
# 10624     1999-12-31
# 2926075   1999-12-31
# 2580122   1999-12-31
# 1334025   1999-12-31
# 5508      1999-12-31
# 1332068   1999-12-31
# 1329863   1999-12-31
#              ...
# 3710475   2019-10-31
# 2896432   2019-10-31
# 3710523   2019-10-31
# 3435143   2019-10-31
# 3685894   2019-10-31
# 3225384   2019-10-31
# 3435217   2019-10-31
# 3225387   2019-10-31
# 3225390   2019-10-31
# 2659561   2019-10-31
# 3225379   2019-10-31
# 2659548   2019-10-31
# ...

# %%
polk_data_clean.to_csv("polk_data_clean.csv",index=False)
