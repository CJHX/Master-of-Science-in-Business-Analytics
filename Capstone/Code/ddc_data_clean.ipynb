# %%
import pandas as pd

# %%
import numpy as np

# %%
client_master = pd.read_csv("client_master.csv")

# %%
client_master.head()
# Out:
#        acctnum accttype acctsubtype        caid                 custname  \
# 0  DETA7000403      OVC     AUCTION  CA11741570  GARY L HAZELLIEF/PUBLIC
# 1  AREN7000438      OVC     AUCTION  CA11740438              ARSALAN ALI
# 2  ALOH7001395      OVC     AUCTION  CA11747260              GARY OSHIRO
# 3        80506      NGC      DEALER  CA11346933          BAVARIAN MOTORS
# 4      5224772      OVC     AUCTION  CA11465278     JETT AUCTION LIMITED
#
#      custcity        custaddrline1 custprovincecode custpostalcode  \
# 0   ANN ARBOR  3085 WHISPERWOOD DR           USA-MI          48105
# 1  VILLA PARK      901 W NORTH AVE           USA-IL          60181
# 2    HONOLULU      3720 MAHINA AVE           USA-HI          96816
# 3     TOMBALL     9428 HUFSMITH RD           USA-TX          77375
# 4  PARKSVILLE     861 ALLSBROOK RD           CAN-BC        V9P 2A9
#
#   externalidtype  externalid          acctaddline1    acctcity acctprovincecd  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
Wholesale = pd.read_csv("Wholesale.csv")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Clean Model_YR

# %%
Wholesale[Wholesale['MODEL_YR']==18]['MODEL_YR']=2018
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
Wholesale = Wholesale[Wholesale['MODEL_YR']>1900]

# %%
Wholesale[Wholesale['MODEL_YR']<1900].shape
# Out:
# (0, 22)

# %%
Wholesale = Wholesale[Wholesale['MODEL_YR']<=2020]

# %%
Wholesale.head()
# Out:
#   AUC_AUCTION_CD BUYER_UID SELLER_UID                VIN              MID  \
# 0            MAA   5004514    4910256  1FTEW1EF7GFD46982  201601757045540
# 1           NASH   5092247    4910256  1FMCU0JD7HUB06187  201701756938959
# 2           NASH   5092247    4910256  1FMCU0J98GUC56903  201601756930838
# 3           MISS   5420499    4910256  1FADP3FE9HL274413  201701772320086
# 4           MISS   5177158    4910256  1FT8W3DTXHEC60427  201701755783113
#
#   UNIT_TYPE_DESC  MODEL_YR MAKE_DESC MODEL_DESC TRIM_DESC BODY_DESC  \
# 0          Truck      2016      Ford      F-150    Lariat     Truck
# 1            SUV      2017      Ford     Escape  Titanium       SUV
# 2            SUV      2016      Ford     Escape  Titanium       SUV
# 3            Car      2017      Ford      Focus        SE     Sedan
# 4          Truck      2017      Ford      F-350    Lariat     Truck
#
#   EXTERIOR_COLOR_DESC  ODOMETER  FINAL_CR_GRADE  CR_FLG  FINAL_PUR_AMT  \
# ...

# %%
Wholesale.describe()
# Out:
#            MODEL_YR      ODOMETER  FINAL_CR_GRADE        CR_FLG  \
# count  1.191471e+06  1.091285e+06   973678.000000  1.191471e+06
# mean   2.013582e+03  7.783400e+04        3.452677  8.219906e-01
# std    4.789867e+00  1.513832e+05        1.045607  3.825208e-01
# min    1.923000e+03  0.000000e+00        0.000000  0.000000e+00
# 25%    2.011000e+03  2.897200e+04        2.700000  1.000000e+00
# 50%    2.016000e+03  5.738400e+04        3.700000  1.000000e+00
# 75%    2.017000e+03  1.159480e+05        4.300000  1.000000e+00
# max    2.020000e+03  1.000000e+08        5.000000  1.000000e+00
#
#        FINAL_PUR_AMT  AT_SALE_NAT_MMR   SOLD_DT_KEY  FLOORPLAN_CUST_OVC_ID  \
# count   1.191441e+06     1.189042e+06  1.191471e+06           4.775070e+05
# mean    1.381358e+04     1.357325e+04  2.019092e+07           6.055841e+06
# std     1.164650e+04     1.121382e+04  8.387545e+01           3.076147e+04
# min     1.000000e+00     0.000000e+00  2.019080e+07           6.048239e+06
# ...

# %%
Wholesale.isna().sum()
# Out:
# AUC_AUCTION_CD                     0
# BUYER_UID                          0
# SELLER_UID                         0
# VIN                                7
# MID                             3437
# UNIT_TYPE_DESC                  1629
# MODEL_YR                           0
# MAKE_DESC                          0
# MODEL_DESC                      1629
# TRIM_DESC                     137230
# BODY_DESC                      26309
# EXTERIOR_COLOR_DESC             7885
# ODOMETER                      100719
# FINAL_CR_GRADE                217793
# CR_FLG                             0
# FINAL_PUR_AMT                     30
# AT_SALE_NAT_MMR                 2429
# SOLD_DT_KEY                        0
# BUYER_HOW_PAID_CD               5620
# FLOORPLAN_CUST_OVC_ID         713964
# FLOORPLAN_CUST_CUR_CUST_NM    713964
# FLOORPLAN_UID                 713920
# dtype: int64

# %%
Wholesale[Wholesale['ODOMETER']==999999].shape
# Out:
# (533, 22)

# %%
Wholesale['ODOMETER'].replace(999999, np.nan, inplace=True)

# %%
Wholesale.to_csv("Wholesale.csv",index=False)

# %%
ddc_listings = pd.read_csv('ddc_listings.csv')

# %%
ddc_listings.head()
# Out:
#       svoc_id  isFD            dealercode                            domain  \
# 0  70705895.0   0.0   pinetreefordlincoln                  pinetreeford.com
# 1  67421021.0   0.0    walkerjonescdjcllc  walkerjoneschryslerjeepdodge.com
# 2  68834621.0   0.0  evansvillemercedesmb            evansvillemercedes.com
# 3  69421969.0   0.0        mileasubarusoa                   mileasubaru.com
# 4    574405.0   0.0            plazalexus                    plazalexus.com
#
#                  vin    vehiclemake    vehiclemodel  vehiclemodelyear  \
# 0  1FTEW1EP1KFC68443           Ford           F-150            2019.0
# 1  3C6TRVCG4JE157071            Ram  ProMaster 2500            2018.0
# 2  WDC0G8EB0LF687867  Mercedes-Benz         GLC 300            2020.0
# 3  JF1VA1A6XL9801603         Subaru             WRX            2020.0
# 4  WDC0G4KB7HF258245  Mercedes-Benz             GLC            2017.0
#
#   vehicletypestring vehiclebodystyle  chromestyleid  mpgcity  mpghighway  \
# ...

# %%
ddc_listings = ddc_listings[ddc_listings["isFD"]==0]

# %%
ddc_listings.shape
# Out:
# (6188408, 19)

# %%
ddc_listings.describe()
# Out:
#             svoc_id       isFD  vehiclemodelyear  chromestyleid       mpgcity  \
# count  6.188408e+06  6188408.0      6.057539e+06   3.335811e+06  1.617399e+06
# mean   4.510492e+07        0.0      2.017253e+03   3.841445e+05  2.254012e+01
# std    3.367752e+07        0.0      1.505077e+01   4.348473e+04  3.463054e+01
# min    6.637600e+04        0.0      1.916000e+03   4.000000e+00  3.000000e+00
# 25%    6.161020e+05        0.0      2.016000e+03   3.800170e+05  1.800000e+01
# 50%    6.584352e+07        0.0      2.019000e+03   3.998260e+05  2.100000e+01
# 75%    7.053137e+07        0.0      2.019000e+03   4.039160e+05  2.600000e+01
# max    1.000527e+08        0.0      2.018100e+04   4.115560e+05  4.300000e+04
#
#          mpghighway  odometermiles         price
# count  1.617434e+06   1.390322e+06  7.032360e+05
# mean   2.947236e+01   3.305733e+04  3.348389e+04
# std    7.068197e+00   2.586834e+05  2.373172e+04
# min    1.100000e+01   0.000000e+00  0.000000e+00
# ...

# %%
ddc_listings.isna().sum()
# Out:
# svoc_id                      0
# isFD                         0
# dealercode                   0
# domain                       0
# vin                          3
# vehiclemake              11700
# vehiclemodel             16686
# vehiclemodelyear             0
# vehicletypestring      1771230
# vehiclebodystyle        956732
# chromestyleid          2721752
# mpgcity                4440132
# mpghighway             4440097
# odometermiles          4667276
# vehicleid              2506758
# vehiclestocknumber      440548
# price                  5354295
# first_seen_datetime          0
# last_seen_datetime           0
# dtype: int64

# %%
ddc_listings = ddc_listings[ddc_listings['vehiclemodelyear']<=2020]

# %%
ddc_listings[ddc_listings['odometermiles']>500000]
# Out:
#              svoc_id  isFD                           dealercode  \
# 38202      1071858.0   0.0                        normsusedcars
# 65813     64002775.0   0.0     fortcollinsdodgechryslerjeepcllc
# 78228     69820163.0   0.0                             pitrekia
# 198184      627565.0   0.0                        koonstytoyota
# 296284    70545947.0   0.0                              ccierin
# 445954    70632477.0   0.0                         grahamnissan
# 508921    70544819.0   0.0                          ccicolumbia
# 525928    56192787.0   0.0                     bennyboydcdjcllc
# 568526      602604.0   0.0          sternbergchryslercentercllc
# 590652    70545061.0   0.0                            ccioakbay
# 750260      602604.0   0.0          sternbergchryslercentercllc
# 768145    70524161.0   0.0                   plattevalleyautone
# 773400    55252559.0   0.0                          bmwofdallas
# 839833    63258197.0   0.0                   autonationusagroup
# ...

# %%
ddc_listings['odometermiles'].replace(999999, np.nan, inplace=True)

# %%
ddc_listings['odometermiles'].replace(9999999, np.nan, inplace=True)

# %%
ddc_listings.head()
# Out:
#       svoc_id  isFD            dealercode                            domain  \
# 0  70705895.0   0.0   pinetreefordlincoln                  pinetreeford.com
# 1  67421021.0   0.0    walkerjonescdjcllc  walkerjoneschryslerjeepdodge.com
# 2  68834621.0   0.0  evansvillemercedesmb            evansvillemercedes.com
# 3  69421969.0   0.0        mileasubarusoa                   mileasubaru.com
# 4    574405.0   0.0            plazalexus                    plazalexus.com
#
#                  vin    vehiclemake    vehiclemodel  vehiclemodelyear  \
# 0  1FTEW1EP1KFC68443           Ford           F-150            2019.0
# 1  3C6TRVCG4JE157071            Ram  ProMaster 2500            2018.0
# 2  WDC0G8EB0LF687867  Mercedes-Benz         GLC 300            2020.0
# 3  JF1VA1A6XL9801603         Subaru             WRX            2020.0
# 4  WDC0G4KB7HF258245  Mercedes-Benz             GLC            2017.0
#
#   vehicletypestring vehiclebodystyle  chromestyleid  mpgcity  mpghighway  \
# ...

# %%
ddc_listings.to_csv("ddc_listings.csv",index=False)
