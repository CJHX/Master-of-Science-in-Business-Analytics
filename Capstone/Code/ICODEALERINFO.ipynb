# %%
# !pip install numpy==1.15.1
# Out:
# ...
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install pyarrow==0.15.1
# Out:
# ...
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import pyarrow

# %%
data = pd.read_parquet('s3://cads-emory-data/data/parquet/vauto/icodealerinfo/part-00000-983dafcd-bc85-4585-9e0f-748e66044309-c000.snappy.parquet')

# %%
data.shape
# Out:
# (78, 9)

# %%
data.head()
# Out:
#                   DealershipName ACTIVE                            DealerGuid  \
# 0                                  true  C80F9FC0-0778-417C-B335-659153BA0FFF
# 1                                  true  C80F9FC0-0778-417C-B335-659153BA0FFF
# 2                                 false  A3AB742F-1229-4C25-A38F-FFBC92571026
# 3  #1 Brookville Chevrolet Buick  false  D601AABD-7AC4-46E3-A990-B9906AFC0B89
# 4  #1 Brookville Chevrolet Buick  false  D601AABD-7AC4-46E3-A990-B9906AFC0B89
#
#     DealerId vAutoID AutoTraderID sourceValue       levelValue  \
# 0       2006                              ATC
# 1       2006                              KBB
# 2       3290                              ATC  Trade In Center
# 3  853242659             56476876         ATC  Trade In Center
# 4  853242659             56476876         KBB  Trade In Center
#
#   Dealer_Dealershipzip
# 0                08003
# 1                08003
# 2
# 3                15825
# 4                15825

# %%
appended_data = []
for x in list(range(0, 256)):
    y = str(100000 + x)[-5:]
    print(y)
    filename = "s3://cads-emory-data/data/parquet/vauto/icodealerinfo/part-" + y + "-983dafcd-bc85-4585-9e0f-748e66044309-c000.snappy.parquet"
    data = pd.read_parquet(filename)
    print(data.shape)
    # store DataFrame in list
    appended_data.append(data)
# see pd.concat documentation for more info
vauto_atc = pd.concat(appended_data)
# Out:
# 00000
# (78, 9)
# 00001
# (79, 9)
# 00002
# (78, 9)
# 00003
# (78, 9)
# 00004
# (73, 9)
# 00005
# (79, 9)
# 00006
# (77, 9)
# 00007
# (77, 9)
# 00008
# (78, 9)
# 00009
# (78, 9)
# 00010
# (78, 9)
# 00011
# (79, 9)
# 00012
# (78, 9)
# 00013
# (75, 9)
# 00014
# (73, 9)
# 00015
# (80, 9)
# 00016
# (78, 9)
# 00017
# (77, 9)
# 00018
# (78, 9)
# 00019
# (79, 9)
# 00020
# (74, 9)
# 00021
# (73, 9)
# 00022
# (76, 9)
# 00023
# (77, 9)
# 00024
# (76, 9)
# 00025
# (73, 9)
# 00026
# (79, 9)
# 00027
# (78, 9)
# 00028
# (78, 9)
# 00029
# (75, 9)
# 00030
# (76, 9)
# 00031
# (76, 9)
# 00032
# (77, 9)
# 00033
# (78, 9)
# 00034
# (75, 9)
# 00035
# (76, 9)
# 00036
# (79, 9)
# 00037
# (75, 9)
# 00038
# (76, 9)
# 00039
# (79, 9)
# 00040
# (75, 9)
# 00041
# (76, 9)
# 00042
# (79, 9)
# 00043
# (77, 9)
# 00044
# (77, 9)
# 00045
# (74, 9)
# 00046
# (73, 9)
# 00047
# (75, 9)
# 00048
# (75, 9)
# 00049
# (76, 9)
# 00050
# (78, 9)
# 00051
# (75, 9)
# 00052
# (76, 9)
# 00053
# (78, 9)
# 00054
# (75, 9)
# 00055
# ...

# %%
vauto_atc.shape
# Out:
# (19596, 9)

# %%
vauto_atc.head(20)
# Out:
#                              DealershipName ACTIVE  \
# 0                                             true
# 1                                             true
# 2                                            false
# 3             #1 Brookville Chevrolet Buick  false
# 4             #1 Brookville Chevrolet Buick  false
# 5   #1 Cochran Ford Chrysler Jeep Dodge Ram   true
# 6   #1 Cochran Ford Chrysler Jeep Dodge Ram   true
# 7    #1 Cochran New & PreOwned Market Place   true
# 8    #1 Cochran New & PreOwned Market Place   true
# 9              #1 Cochran Nissan West Hills   true
# 10             #1 Cochran Nissan West Hills   true
# 11             #1 Cochran Nissan West Hills   true
# 12                   #1 Cochran North Hills   true
# 13                   #1 Cochran North Hills   true
# 14                #1 Cochran of Monroeville   true
# 15                #1 Cochran of Monroeville   true
# 16                #1 Cochran of Monroeville   true
# ...

# %%
vauto_atc.columns
# Out:
# Index(['DealershipName', 'ACTIVE', 'DealerGuid', 'DealerId', 'vAutoID',
#        'AutoTraderID', 'sourceValue', 'levelValue', 'Dealer_Dealershipzip'],
#       dtype='object')

# %%
vauto_atc.to_csv("icodealerinfo.csv",index=False)
