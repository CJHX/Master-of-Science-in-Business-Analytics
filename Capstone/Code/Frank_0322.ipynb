# %%
import pandas as pd
import numpy as np

# %%
Wholesale = pd.read_csv("wholesale_321.csv").iloc[:, 1:]
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pd.isnull(Wholesale).sum()
# Out:
# caid                               0
# Vin                                0
# Year                               0
# Make                               0
# Model                            571
# Trim                           33064
# Mileage                        31229
# Date                               0
# MIDMapAlgorithm                    0
# mid15                           1900
# VPID                            1982
# MMR_adj_current                 7619
# RMI_adj_current                19279
# AvgPrice                        2339
# avgmiles                        2339
# Velocity                        2904
# Salesefficiency                 2343
# AvgDaysToSell                   2339
# vol_tier                        2339
# availability                    2340
# inventory                       3042
# spread_current                 20766
# FINAL_PUR_AMT                      1
# BUYER_HOW_PAID_CD                712
# FLOORPLAN_CUST_OVC_ID         211556
# ...

# %%
Wholesale.insert(1, "Source", "Wholesale")

# %%
Wholesale = Wholesale.assign(isca=np.where(Wholesale.caid.isnull(), 0, 1))

# %%
Wholesale.loc[Wholesale['isca'] == 1, 'no_caid'] = np.nan
Wholesale.loc[Wholesale['isca'] == 0, 'no_caid'] = 'wholesale' + Wholesale.BUYER_UID.astype(str)

# %%
len(Wholesale)
# Out:
# 1191471

# %%
sum(Wholesale['isca'])
# Out:
# 1104514

# %%
cols = Wholesale.columns.tolist()

# %%
cols = ['isca',
'caid',
'no_caid',
 'Source',
 'Vin',
 'Year',
 'Make',
 'Model',
 'Trim',
 'Mileage',
 'Date',
 'MIDMapAlgorithm',
 'mid15',
 'VPID',
 'MMR_adj_current',
 'RMI_adj_current',
 'AvgPrice',
 'avgmiles',
 'Velocity',
 'Salesefficiency',
 'AvgDaysToSell',
 'vol_tier',
 'availability',
 'inventory',
 'spread_current',
 'FINAL_PUR_AMT',
 'BUYER_HOW_PAID_CD',
 'FLOORPLAN_CUST_OVC_ID',
 'FLOORPLAN_CUST_CUR_CUST_NM']

# %%
Wholesale = Wholesale[cols]

# %%
Wholesale = Wholesale.rename(columns = {'FINAL_PUR_AMT':'wholesale_price'})

# %%
Wholesale = Wholesale.rename(columns = {'BUYER_HOW_PAID_CD':'buyer_how_paid_cd'})
Wholesale = Wholesale.rename(columns = {'FLOORPLAN_CUST_OVC_ID':'floorplan_cust_ovc_id'})
Wholesale = Wholesale.rename(columns = {'FLOORPLAN_CUST_CUR_CUST_NM':'floorplan_cur_cust_nm'})

# %%
Wholesale = Wholesale.sort_values(by=['caid','no_caid'])

# %%
Wholesale.head()
# Out:
#    isca        caid no_caid     Source                Vin  Year    Make  \
# 0     1  CA11197386     NaN  Wholesale  W04GM6SX6J1128183  2018   Buick
# 1     1  CA11197386     NaN  Wholesale  5N1AR2MN3EC604302  2014  Nissan
# 2     1  CA11197386     NaN  Wholesale  1C6RR7KT5ES407912  2014     Ram
# 3     1  CA11197386     NaN  Wholesale  1N6AD0ER3GN711038  2016  Nissan
# 4     1  CA11197386     NaN  Wholesale  1G4GD5G32FF220189  2015   Buick
#
#              Model          Trim   Mileage        Date MIDMapAlgorithm  \
# 0  Regal Sportback  Preferred II   21415.0  2019-08-07           Exact
# 1       Pathfinder            SL  106072.0  2019-08-21           Exact
# 2             1500     Tradesman  108699.0  2019-09-25           Exact
# 3         Frontier             S   57593.0  2019-08-21           Exact
# 4         LaCrosse     Premium I  107588.0  2019-08-14           Exact
#
#           mid15                        VPID  MMR_adj_current  RMI_adj_current  \
# ...

# %%
Wholesale.to_csv('wholesale_321.csv',index=False)

# %%
ddc = pd.read_csv('ddc_321.csv').iloc[:, 1:]
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ddc.shape
# Out:
# (6057530, 24)

# %%
pd.isnull(ddc).sum()
# Out:
# isca                     0
# caid               1762089
# no_caid            4295441
# Source                   0
# Vin                      4
# Year                     0
# Make                 11701
# Model                16686
# Trim                956732
# Mileage            4667276
# Date                     0
# MIDMapAlgorithm          0
# mid15                47272
# VPID                 88019
# MMR_adj_current    1113352
# RMI_adj_current     804082
# AvgPrice            378347
# avgmiles            378347
# Velocity            512476
# Salesefficiency     378734
# AvgDaysToSell       378347
# vol_tier            378347
# availability        378349
# inventory           386440
# spread_current     1294940
# price              5354295
# dtype: int64

# %%
ddc.insert(1, "Source", "ddc")

# %%
ddc = ddc.assign(isca=np.where(ddc.caid.isnull(), 0, 1))

# %%
ddc.loc[ddc['isca'] == 1, 'no_caid'] = np.nan
ddc.loc[ddc['isca'] == 0, 'no_caid'] = 'ddc_' + ddc.svoc_id.astype(str)

# %%
cols = ddc.columns.tolist()

# %%
cols = ['isca',
'caid',
'no_caid',
 'Source',
 'Vin',
 'Year',
 'Make',
 'Model',
 'Trim',
 'Mileage',
 'Date',
 'MIDMapAlgorithm',
 'mid15',
 'VPID',
 'MMR_adj_current',
 'RMI_adj_current',
 'AvgPrice',
 'avgmiles',
 'Velocity',
 'Salesefficiency',
 'AvgDaysToSell',
 'vol_tier',
 'availability',
 'inventory',
 'spread_current',
 'price']

# %%
ddc = ddc[cols]

# %%
ddc = ddc.sort_values(by=['caid','no_caid'])

# %%
ddc.head()
# Out:
#    isca        caid no_caid Source                Vin  Year     Make  \
# 0     1  CA11197380     NaN    ddc  5NPE34AF5GH274704  2016  Hyundai
# 1     1  CA11197380     NaN    ddc  2HGFB6E50DH705377  2013    Honda
# 2     1  CA11197380     NaN    ddc  1GTR2VE7XCZ218323  2012      GMC
# 3     1  CA11197387     NaN    ddc  WP0CB2A84KS228839  2019  Porsche
# 4     1  CA11197387     NaN    ddc  WP1AG2A52HLB50755  2017  Porsche
#
#          Model       Trim  Mileage        Date MIDMapAlgorithm         mid15  \
# 0       Sonata      Sedan  19310.0  2019-10-20           Exact  2.016059e+14
# 1        Civic      Other      NaN  2019-10-12           Exact  2.013023e+14
# 2  Sierra 1500      Truck      NaN  2019-10-30           Exact  2.012022e+14
# 3  718 Boxster  Cabriolet      4.0  2019-10-30         Popular  2.019045e+14
# 4        Macan        SUV  23265.0  2019-10-31           Exact  2.017045e+14
#
#                        VPID  MMR_adj_current  RMI_adj_current  AvgPrice  \
# ...

# %%
ddc.to_csv('ddc_321.csv',index=False)

# %%
atc = pd.read_csv('atc_321.csv').iloc[:, 1:]
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
atc.shape
# Out:
# (9215447, 24)

# %%
atc.head()
# Out:
#          caid                Vin  Year        Make              Model  \
# 0  CA11197387  WP0AC2A92ES183188  2014     Porsche                911
# 1  CA11197387  WP1AB2A58JLB40543  2018     Porsche              Macan
# 2  CA11197387  WP0CB29895U731201  2005     Porsche            Boxster
# 3  CA11197387  SALWR2WF9EA359025  2014  Land Rover  Range Rover Sport
# 4  CA11197387  WP1AG2A51HLB54957  2017     Porsche              Macan
#
#         Trim  Mileage        Date MIDMapAlgorithm         mid15  \
# 0  GT3 Coupe   8331.0  2019-09-20           Exact  2.014045e+14
# 1          S    401.0  2019-09-26           Exact  2.018045e+14
# 2          S  69154.0  2019-08-12           Exact  2.005044e+14
# 3        HSE  53244.0  2019-08-16           Exact  2.014103e+14
# 4        GTS  16627.0  2019-08-02           Exact  2.017045e+14
#
#                                 VPID  MMR_adj_current  RMI_adj_current  \
# 0                   2014_Porsche_911         109500.0              NaN
# ...

# %%
atc.insert(1, "Source", "atc")
atc = atc.assign(isca=np.where(atc.caid.isnull(), 0, 1))
atc.loc[atc['isca'] == 1, 'no_caid'] = np.nan
atc.loc[atc['isca'] == 0, 'no_caid'] = 'atc_' + atc.CUSTOMER_ID.astype(str)

# %%
atc = atc.rename(columns = {'PRICE_NUM':'price'})

# %%
cols = ['isca',
'caid',
'no_caid',
 'Source',
 'Vin',
 'Year',
 'Make',
 'Model',
 'Trim',
 'Mileage',
 'Date',
 'MIDMapAlgorithm',
 'mid15',
 'VPID',
 'MMR_adj_current',
 'RMI_adj_current',
 'AvgPrice',
 'avgmiles',
 'Velocity',
 'Salesefficiency',
 'AvgDaysToSell',
 'vol_tier',
 'availability',
 'inventory',
 'spread_current',
 'price']

# %%
atc = atc[cols]

# %%
atc = atc.sort_values(by=['caid','no_caid'])

# %%
atc.head()
# Out:
#    isca        caid no_caid Source                Vin  Year        Make  \
# 0     1  CA11197387     NaN    atc  WP0AC2A92ES183188  2014     Porsche
# 1     1  CA11197387     NaN    atc  WP1AB2A58JLB40543  2018     Porsche
# 2     1  CA11197387     NaN    atc  WP0CB29895U731201  2005     Porsche
# 3     1  CA11197387     NaN    atc  SALWR2WF9EA359025  2014  Land Rover
# 4     1  CA11197387     NaN    atc  WP1AG2A51HLB54957  2017     Porsche
#
#                Model       Trim  Mileage        Date MIDMapAlgorithm  \
# 0                911  GT3 Coupe   8331.0  2019-09-20           Exact
# 1              Macan          S    401.0  2019-09-26           Exact
# 2            Boxster          S  69154.0  2019-08-12           Exact
# 3  Range Rover Sport        HSE  53244.0  2019-08-16           Exact
# 4              Macan        GTS  16627.0  2019-08-02           Exact
#
#           mid15                               VPID  MMR_adj_current  \
# ...

# %%
atc.shape
# Out:
# (9215447, 26)

# %%
pd.isnull(atc).sum()
# Out:
# isca                     0
# caid               2226067
# no_caid            6989380
# Source                   0
# Vin                     29
# Year                     0
# Make                     0
# Model                    0
# Trim                     0
# Mileage                  0
# Date                     0
# MIDMapAlgorithm          0
# mid15                20339
# VPID                 62405
# MMR_adj_current    1400670
# RMI_adj_current    1178222
# AvgPrice            429366
# avgmiles            429366
# Velocity            649661
# Salesefficiency     429452
# AvgDaysToSell       429366
# vol_tier            429366
# availability        429367
# inventory           453748
# spread_current     1742968
# price                    0
# dtype: int64

# %%
atc.to_csv('atc_321.csv',index=False)

# %%
vauto_recent = pd.read_csv('0322_JZ_merge.csv').iloc[:, 1:]

# %%
vauto_recent.head()
# Out:
#   Source                Vin  Year  Make       Model                Trim  \
# 0    VRN  1C6SRFFT4KN744751  2019   Ram        1500  Big Horn/Lone Star
# 1    VRN  1FMJU1HT3KEA63995  2019  Ford  Expedition                 XLT
# 2    VRN  1FMSK8DH4LGA36038  2020  Ford    Explorer                 XLT
# 3    VRN  1FT7W2A6XKEF37170  2019  Ford     F-250SD                  XL
# 4    VRN  1FTFW1RG2KFB68284  2019  Ford       F-150              Raptor
#
#    Mileage        Date MIDMapAlgorithm         mid15  \
# 0      NaN  2019-09-27           Exact  2.019333e+14
# 1      NaN  2019-08-29           Exact  2.019018e+14
# 2     24.0  2019-10-07           Exact  2.020018e+14
# 3      4.0  2019-09-06         Popular  2.019018e+14
# 4     12.0  2019-08-28           Exact  2.019018e+14
#
#                              VPID  MMR_adj_current  RMI_adj_current  AvgPrice  \
# 0                   2019_Ram_1500          31600.0          35200.0   35522.0
# ...

# %%
vauto_recent[vauto_recent['caid'].str.match(pat = '(CA[0-9])')].head()
# Out:
#   Source                Vin  Year       Make       Model                Trim  \
# 0    VRN  1C6SRFFT4KN744751  2019        Ram        1500  Big Horn/Lone Star
# 1    VRN  1FMJU1HT3KEA63995  2019       Ford  Expedition                 XLT
# 3    VRN  1FT7W2A6XKEF37170  2019       Ford     F-250SD                  XL
# 5    VRN  1G1BE5SM7K7105984  2019  Chevrolet       Cruze                  LT
# 6    VRN  1G1JF6SB2K4144626  2019  Chevrolet       Sonic             Premier
#
#    Mileage        Date MIDMapAlgorithm         mid15  \
# 0      NaN  2019-09-27           Exact  2.019333e+14
# 1      NaN  2019-08-29           Exact  2.019018e+14
# 3      4.0  2019-09-06         Popular  2.019018e+14
# 5    287.0  2019-09-01           Exact  2.019012e+14
# 6      1.0  2019-08-13           Exact  2.019012e+14
#
#                              VPID  MMR_adj_current  RMI_adj_current  AvgPrice  \
# 0                   2019_Ram_1500          31600.0          35200.0   35522.0
# ...

# %%
vauto_recent.loc[vauto_recent['caid'].str.match(pat = '(CA[0-9])'), 'real_caid'] = vauto_recent.caid

# %%
vauto_recent = vauto_recent.rename(columns = {'caid':'id'})
vauto_recent = vauto_recent.rename(columns = {'real_caid':'caid'})

# %%
vauto_recent = vauto_recent.assign(isca=np.where(vauto_recent.caid.isnull(), 0, 1))
vauto_recent.loc[vauto_recent['isca'] == 1, 'no_caid'] = np.nan
vauto_recent.loc[vauto_recent['isca'] == 0, 'no_caid'] = vauto_recent.id

# %%
vauto_recent = vauto_recent[cols]

# %%
vauto_recent = vauto_recent.sort_values(by=['caid','no_caid'])

# %%
vauto_recent.head()
# Out:
#         isca        caid no_caid Source                Vin  Year     Make  \
# 23120      1  CA11197387     NaN    VRN  WP0CB2A89JS229094  2018  Porsche
# 70202      1  CA11197387     NaN    VRN  WP1AA2AY4KDA17024  2019  Porsche
# 95655      1  CA11197387     NaN    VRN  WP1AB2A59KLB32078  2019  Porsche
# 138711     1  CA11197387     NaN    VRN  WP0AD2A90KS140123  2019  Porsche
# 229782     1  CA11197387     NaN    VRN  WP1AE2AY8KDA51407  2019  Porsche
#
#               Model      Trim  Mileage        Date MIDMapAlgorithm  \
# 23120   718 Boxster       NaN     25.0  2019-09-28           Exact
# 70202       Cayenne      Base      NaN  2019-09-13           Exact
# 95655         Macan         S     10.0  2019-10-22           Exact
# 138711          911     Turbo      NaN  2019-10-05           Exact
# 229782      Cayenne  S Hybrid      NaN  2019-09-15           Exact
#
#                mid15                      VPID  MMR_adj_current  \
# ...

# %%
pd.isnull(vauto_recent).sum()
# Out:
# isca                     0
# caid                844046
# no_caid            3069010
# Source                   0
# Vin                      0
# Year                     0
# Make                     0
# Model                    0
# Trim                 87762
# Mileage             561864
# Date                     0
# MIDMapAlgorithm          0
# mid15                15503
# VPID                 20391
# MMR_adj_current     342189
# RMI_adj_current     394246
# AvgPrice             74634
# avgmiles             74634
# Velocity            116984
# Salesefficiency      74720
# AvgDaysToSell        74634
# vol_tier             74634
# availability         74634
# inventory            84835
# spread_current      547343
# price               316197
# dtype: int64

# %%
vauto_recent.shape
# Out:
# (3913056, 26)

# %%
vauto_recent.to_csv('vauto_recent_322.csv',index=False)

# %%
vauto_sold = pd.read_csv('0322_Carl_merge.csv').iloc[:, 1:]
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
vauto_sold.columns
# Out:
# Index(['EFFECTIVE_START_TS', 'LATEST_VERSION_IND', 'Source', 'body_bed_style',
#        'body_cab_style', 'body_description', 'body_door_count',
#        'body_roof_style', 'body_type', 'categorized_equipment_ids', 'created',
#        'days_ininventory', 'drive_train_type', 'engine_cylinder_count',
#        'engine_description', 'engine_displacement', 'engine_fuel_type',
#        'exterior_base_color', 'exterior_color', 'interior_color',
#        'interior_description', 'interior_material', 'is_certified',
#        'last_seen', 'list_price', 'new_used', 'postal_code', 'seller_name',
#        'series', 'series_detail', 'stock_number', 'transmission_description',
#        'transmission_gear_count', 'transmission_type', 'veh_segment',
#        'veh_type', 'Trim', 'Vin', 'Year', 'Make', 'Model', 'FullTrim',
#        'Mileage', 'Date', 'MIDMapAlgorithm', 'mid15', 'VPID',
#        'MMR_adj_current', 'RMI_adj_current', 'AvgPrice', 'avgmiles',
# ...

# %%
vauto_sold.loc[vauto_sold['caid'].str.match(pat = '(CA[0-9])'), 'real_caid'] = vauto_sold.caid
vauto_sold = vauto_sold.rename(columns = {'caid':'id'})
vauto_sold = vauto_sold.rename(columns = {'real_caid':'caid'})

# %%
vauto_sold = vauto_sold.assign(isca=np.where(vauto_sold.caid.isnull(), 0, 1))
vauto_sold.loc[vauto_sold['isca'] == 1, 'no_caid'] = np.nan
vauto_sold.loc[vauto_sold['isca'] == 0, 'no_caid'] = vauto_sold.id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f18e75d8bd17> in <module>()
#       2 vauto_sold.loc[vauto_sold['isca'] == 1, 'no_caid'] = np.nan
#       3 vauto_sold.loc[vauto_sold['isca'] == 0, 'no_caid'] = vauto_sold.id
# ----> 4 vauto_sold = vauto_sold[cols]
#       5 vauto_sold = vauto_sold.sort_values(by=['caid','no_caid'])
#
# NameError: name 'cols' is not defined

# %%
vauto_sold = vauto_sold.rename(columns = {'list_price':'price'})
vauto_sold = vauto_sold[cols]
vauto_sold = vauto_sold.sort_values(by=['caid','no_caid'])

# %%
vauto_sold.head()
# Out:
#         isca        caid no_caid Source                Vin  Year  \
# 24136      1  CA11197387     NaN   VASC  1G1YY22G5V5108618  1997
# 39147      1  CA11197387     NaN   VASC  WDBUF56X09B370706  2009
# 100000     1  CA11197387     NaN   VASC  WP1AE2A25HLA72676  2017
# 180500     1  CA11197387     NaN   VASC  WP0AC2A99JS174742  2018
# 300646     1  CA11197387     NaN   VASC  WP0AB299X3S686195  2003
#
#                  Make     Model        Trim   Mileage        Date  \
# 24136       Chevrolet  Corvette       Base    51009.0  2019-08-30
# 39147   Mercedes-Benz   E-Class  E 350 Base  165898.0  2019-10-23
# 100000        Porsche   Cayenne   S Hybrid    20108.0  2019-09-11
# 180500        Porsche       911        GT3     1847.0  2019-10-19
# 300646        Porsche       911      Turbo    55507.0  2019-10-23
#
#        MIDMapAlgorithm         mid15                        VPID  \
# 24136            Exact  1.997011e+14     1997_Chevrolet_Corvette
# ...

# %%
vauto_sold.shape
# Out:
# (8876047, 26)

# %%
pd.isnull(vauto_sold).sum()
# Out:
# isca                     0
# caid               1925195
# no_caid            6950852
# Source                   0
# Vin                      0
# Year                     0
# Make                     0
# Model                    0
# Trim                194081
# Mileage            1389259
# Date                     0
# MIDMapAlgorithm          0
# mid15                35436
# VPID                 46022
# MMR_adj_current     770985
# RMI_adj_current     896115
# AvgPrice            166608
# avgmiles            166608
# Velocity            261709
# Salesefficiency     166771
# AvgDaysToSell       166608
# vol_tier            166608
# availability        166608
# inventory           189747
# spread_current     1238506
# price              1321739
# dtype: int64

# %%
vauto_sold.to_csv('vauto_sold_322.csv',index=False)

# %%
del vauto_sold

# %%
polk = pd.read_csv('polk_322.csv').iloc[:, 1:]

# %%
pd.isnull(polk).sum()
# Out:
# caid                730806
# Source                   0
# Vin                      0
# Year                     0
# Make                     0
# Model                    0
# Trim                123633
# Mileage             709131
# Date                     0
# MIDMapAlgorithm          0
# mid15                12284
# VPID                 28972
# MMR_adj_current     731769
# RMI_adj_current     569770
# AvgPrice            177839
# avgmiles            177839
# Velocity            292433
# Salesefficiency     177967
# AvgDaysToSell       177839
# vol_tier            177839
# availability        177839
# inventory           179232
# spread_current      877204
# polk_con_num        233714
# dealer_name              0
# purchase_lease           0
# trans_price        2286433
# isca                     0
# isnum                    0
# no_caid            2684837
# dtype: int64

# %%
polk.insert(1, "Source", "polk")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-174f5661d232> in <module>()
#       1 polk.insert(1, "Source", "polk")
# ----> 2 polk = polk.assign(isca=np.where(polk.caid.isnull(), 0, 1))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'caid'

# %%
polk = polk.rename(columns = {'ca_id':'caid'})
polk = polk.assign(isca=np.where(polk.caid.isnull(), 0, 1))

# %%
polk = polk.assign(isnum=np.where(polk.polk_con_num.isnull(), 0, 1))

# %%
polk.loc[polk['isca'] == 1, 'no_caid'] = np.nan
polk.loc[(polk['isca'] == 0) & (polk['isnum'] == 1), 'no_caid'] = 'polk_' + polk.polk_con_num.astype(str)
polk.loc[(polk['isca'] == 0) & (polk['isnum'] == 0), 'no_caid'] = 'polk_' + polk.dealer_name.astype(str)

# %%
polk = polk.rename(columns = {'trans_price':'price'})
polk = polk[cols]
polk = polk.sort_values(by=['caid','no_caid'])

# %%
polk.shape
# Out:
# (3415643, 26)

# %%
polk.head()
# Out:
#        isca        caid no_caid Source                Vin  Year Make   Model  \
# 31617     1  CA11197386     NaN   polk  3GTU9DED5KG109644  2019  GMC  SIERRA
# 31756     1  CA11197386     NaN   polk  1GKS1BKC8KR374884  2019  GMC   YUKON
# 31973     1  CA11197386     NaN   polk  1GTU9FEL5KZ381226  2019  GMC  SIERRA
# 42758     1  CA11197386     NaN   polk  3GTU9DED0KG253215  2019  GMC  SIERRA
# 61351     1  CA11197386     NaN   polk  1GTU9BED7KZ381794  2019  GMC  SIERRA
#
#       Trim  Mileage        Date MIDMapAlgorithm         mid15  \
# 31617  15N    124.0  2019-08-03           Exact  2.019022e+14
# 31756  SLT      5.0  2019-08-03           Exact  2.019022e+14
# 31973  15N      4.0  2019-08-03           Exact  2.019022e+14
# 42758  15N     28.0  2019-08-04           Exact  2.019022e+14
# 61351  15N     18.0  2019-08-05           Exact  2.019022e+14
#
#                        VPID  MMR_adj_current  RMI_adj_current  AvgPrice  \
# ...

# %%
Wholesale = pd.read_csv("wholesale_321.csv")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Wholesale.head()
# Out:
#    isca        caid no_caid     Source                Vin  Year    Make  \
# 0     1  CA11197386     NaN  Wholesale  W04GM6SX6J1128183  2018   Buick
# 1     1  CA11197386     NaN  Wholesale  5N1AR2MN3EC604302  2014  Nissan
# 2     1  CA11197386     NaN  Wholesale  1C6RR7KT5ES407912  2014     Ram
# 3     1  CA11197386     NaN  Wholesale  1N6AD0ER3GN711038  2016  Nissan
# 4     1  CA11197386     NaN  Wholesale  1G4GD5G32FF220189  2015   Buick
#
#              Model          Trim   Mileage  ... Salesefficiency AvgDaysToSell  \
# 0  Regal Sportback  Preferred II   21415.0  ...        0.466495          20.0
# 1       Pathfinder            SL  106072.0  ...        0.543061          17.0
# 2             1500     Tradesman  108699.0  ...        0.519934          17.0
# 3         Frontier             S   57593.0  ...        0.686963          19.0
# 4         LaCrosse     Premium I  107588.0  ...        0.548013          17.0
#
# ...

# %%
atc = pd.read_csv('atc_321.csv')
ddc = pd.read_csv('ddc_321.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
vauto_sold = pd.read_csv('vauto_sold_322.csv')
vauto_recent = pd.read_csv('vauto_recent_322.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
polk = pd.read_csv('polk_322.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Wholesale = pd.concat([Wholesale,atc], axis=0, ignore_index=True)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
del atc
Wholesale = pd.concat([Wholesale,ddc], axis=0, ignore_index=True)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app

# %%
del ddc
Wholesale = pd.concat([Wholesale,vauto_sold], axis=0, ignore_index=True)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app

# %%
del vauto_sold
Wholesale = pd.concat([Wholesale,vauto_recent], axis=0, ignore_index=True)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app

# %%
del vauto_recent
Wholesale = pd.concat([Wholesale,polk], axis=0, ignore_index=True)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app

# %%
Wholesale.shape
# Out:
# (32669194, 30)

# %%
Wholesale.columns
# Out:
# Index(['isca', 'caid', 'no_caid', 'Source', 'Vin', 'Year', 'Make', 'Model',
#        'Trim', 'Mileage', 'Date', 'MIDMapAlgorithm', 'mid15', 'VPID',
#        'MMR_adj_current', 'RMI_adj_current', 'AvgPrice', 'avgmiles',
#        'Velocity', 'Salesefficiency', 'AvgDaysToSell', 'vol_tier',
#        'availability', 'inventory', 'spread_current', 'price',
#        'wholesale_price', 'buyer_how_paid_cd', 'floorplan_cur_cust_nm',
#        'floorplan_cust_ovc_id'],
#       dtype='object')

# %%
cols = ['isca',
'caid',
'no_caid',
 'Source',
 'Vin',
 'Year',
 'Make',
 'Model',
 'Trim',
 'Mileage',
 'Date',
 'MIDMapAlgorithm',
 'mid15',
 'VPID',
 'MMR_adj_current',
 'RMI_adj_current',
 'AvgPrice',
 'avgmiles',
 'Velocity',
 'Salesefficiency',
 'AvgDaysToSell',
 'vol_tier',
 'availability',
 'inventory',
 'spread_current',
 'price',
'wholesale_price','buyer_how_paid_cd','floorplan_cur_cust_nm','floorplan_cust_ovc_id']

# %%
Wholesale = Wholesale[cols]

# %%
Wholesale = Wholesale.sort_values(by=['caid','no_caid','Source','Vin','Date'])

# %%
Wholesale.head(50)
# Out:
#           isca        caid no_caid     Source                Vin  Year  \
# 10406920     1  CA11197380     NaN        ddc  1GTR2VE7XCZ218323  2012
# 10406919     1  CA11197380     NaN        ddc  2HGFB6E50DH705377  2013
# 10406918     1  CA11197380     NaN        ddc  5NPE34AF5GH274704  2016
# 44           1  CA11197386     NaN  Wholesale  19XFA1F59AE046628  2010
# 58           1  CA11197386     NaN  Wholesale  19XFB2F55DE031146  2013
# 64           1  CA11197386     NaN  Wholesale  1C4RJEBG0FC926563  2015
# 70           1  CA11197386     NaN  Wholesale  1C4RJEBG8FC755321  2015
# 36           1  CA11197386     NaN  Wholesale  1C4RJECT2DC600644  2013
# 2            1  CA11197386     NaN  Wholesale  1C6RR7KT5ES407912  2014
# 13           1  CA11197386     NaN  Wholesale  1C6RR7LG4ES463227  2014
# 62           1  CA11197386     NaN  Wholesale  1FADP3J22EL141744  2014
# 73           1  CA11197386     NaN  Wholesale  1FM5K7F81DGA34494  2013
# ...

# %%
Wholesale.to_csv('data_323.csv',index=False)

# %%
data= pd.read_csv('data_323.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.shape
# Out:
# (32669194, 30)

# %%
NGC = pd.read_csv('NGC_323.csv')

# %%
NGC.head()
# Out:
#          caid                Vin  NGC_purchase_price  NGC_floored_amount
# 0  CA11203615  1GCEC14X27Z180307              5550.0              5550.0
# 1  CA11203615  JTEHD20V556043246              4785.0              4785.0
# 2  CA11203615  3GNBABDV9AS580874               995.0               995.0
# 3  CA11203615  JTLKE50E691093198              3665.0              3665.0
# 4  CA11203615  5Y2SL67897Z419839              3265.0              3265.0

# %%
NGC = NGC.drop_duplicates(subset=['caid','Vin'])

# %%
NGC.shape
# Out:
# (732004, 4)

# %%
data = pd.merge(data, NGC, left_on=['caid','Vin'], right_on = ['caid','Vin'], how='left')

# %%
data.shape
# Out:
# (32669194, 30)

# %%
pd.isnull(data).sum()
# Out:
# isca                            0
# caid                      7575160
# no_caid                  25094034
# Source                          0
# Vin                            40
# Year                            0
# Make                        11701
# Model                       18315
# Trim                      1499438
# Mileage                   7428249
# Date                            0
# MIDMapAlgorithm                 0
# mid15                      142713
# VPID                       258333
# MMR_adj_current           4397153
# RMI_adj_current           3963557
# AvgPrice                  1241749
# avgmiles                  1241749
# Velocity                  1852260
# Salesefficiency           1242606
# AvgDaysToSell             1241749
# vol_tier                  1241749
# availability              1241755
# inventory                 1313338
# spread_current            5826665
# price                    10470135
# wholesale_price          31477753
# ...

# %%
data = data.drop(['mid15', 'VPID'], axis=1)

# %%
data = data.drop(['wholesale_price'], axis=1)

# %%
Wholesale = pd.read_csv("wholesale_321.csv")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Wholesale = Wholesale[['caid','Vin','wholesale_price']]

# %%
Wholesale.head()
# Out:
#          caid                Vin  wholesale_price
# 0  CA11197386  W04GM6SX6J1128183          16400.0
# 1  CA11197386  5N1AR2MN3EC604302          11000.0
# 2  CA11197386  1C6RR7KT5ES407912          13000.0
# 3  CA11197386  1N6AD0ER3GN711038          15700.0
# 4  CA11197386  1G4GD5G32FF220189          11200.0

# %%
Wholesale.shape
# Out:
# (1191032, 3)

# %%
Wholesale = Wholesale.drop_duplicates(subset=['caid','Vin'])

# %%
data = pd.merge(data, Wholesale, left_on=['caid','Vin'], right_on = ['caid','Vin'], how='left')

# %%
data.to_csv('data_323.csv',index=False)

# %%
del Wholesale

# %%
data.head()
# Out:
#    isca        caid no_caid     Source                Vin  Year     Make  \
# 0     1  CA11197380     NaN        ddc  1GTR2VE7XCZ218323  2012      GMC
# 1     1  CA11197380     NaN        ddc  2HGFB6E50DH705377  2013    Honda
# 2     1  CA11197380     NaN        ddc  5NPE34AF5GH274704  2016  Hyundai
# 3     1  CA11197386     NaN  Wholesale  19XFA1F59AE046628  2010    Honda
# 4     1  CA11197386     NaN  Wholesale  19XFB2F55DE031146  2013    Honda
#
#          Model   Trim  Mileage        Date MIDMapAlgorithm  MMR_adj_current  \
# 0  Sierra 1500  Truck      NaN  2019-10-30           Exact          11750.0
# 1        Civic  Other      NaN  2019-10-12           Exact          10150.0
# 2       Sonata  Sedan  19310.0  2019-10-20           Exact          16000.0
# 3        Civic     LX  79889.0  2019-08-21           Exact           4225.0
# 4        Civic     LX  80827.0  2019-08-21           Exact           7075.0
#
#    RMI_adj_current  AvgPrice  avgmiles Velocity  Salesefficiency  \
# ...

# %%
pd.isnull(data).sum()
# Out:
# isca                            0
# caid                      7575160
# no_caid                  25094034
# Source                          0
# Vin                            40
# Year                            0
# Make                        11701
# Model                       18315
# Trim                      1499438
# Mileage                   7428249
# Date                            0
# MIDMapAlgorithm                 0
# MMR_adj_current           4397153
# RMI_adj_current           3963557
# AvgPrice                  1241749
# avgmiles                  1241749
# Velocity                  1852260
# Salesefficiency           1242606
# AvgDaysToSell             1241749
# vol_tier                  1241749
# availability              1241755
# inventory                 1313338
# spread_current            5826665
# price                    10470135
# buyer_how_paid_cd        31483343
# floorplan_cur_cust_nm    32191687
# floorplan_cust_ovc_id    32191687
# ...
