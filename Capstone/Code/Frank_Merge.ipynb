# %%
import pandas as pd

# %%
Wholesale = pd.read_csv("Wholesale.csv")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Wholesale.head()
# Out:
#   AUC_AUCTION_CD BUYER_UID SELLER_UID                VIN              MID  \
# 0            MAA   5004514    4910256  1FTEW1EF7GFD46982  201601757045540
# 1           NASH   5092247    4910256  1FMCU0JD7HUB06187  201701756938959
# 2           NASH   5092247    4910256  1FMCU0J98GUC56903  201601756930838
# 3           MISS   5420499    4910256  1FADP3FE9HL274413  201701772320086
# 4           MISS   5177158    4910256  1FT8W3DTXHEC60427  201701755783113
#
#   UNIT_TYPE_DESC  MODEL_YR MAKE_DESC MODEL_DESC TRIM_DESC  ...  ODOMETER  \
# 0          Truck      2016      Ford      F-150    Lariat  ...   36524.0
# 1            SUV      2017      Ford     Escape  Titanium  ...   20970.0
# 2            SUV      2016      Ford     Escape  Titanium  ...   19531.0
# 3            Car      2017      Ford      Focus        SE  ...   36482.0
# 4          Truck      2017      Ford      F-350    Lariat  ...  109622.0
#
#   FINAL_CR_GRADE  CR_FLG  FINAL_PUR_AMT  AT_SALE_NAT_MMR  SOLD_DT_KEY  \
# ...

# %%
Wholesale.shape
# Out:
# (1191471, 22)

# %%
pd.set_option('display.max_columns', None)

# %%
Wholesale_cleaned = pd.DataFrame()

# %%
Wholesale_cleaned['Key'] = Wholesale['BUYER_UID']

# %%
Wholesale_cleaned['Source'] = 'wholesale'

# %%
Wholesale_cleaned['Vin'] = Wholesale['VIN']

# %%
Wholesale_cleaned['Year'] = Wholesale['MODEL_YR']

# %%
Wholesale_cleaned['Make'] = Wholesale['MAKE_DESC']

# %%
Wholesale_cleaned['Model'] = Wholesale['MODEL_DESC']

# %%
Wholesale_cleaned['Trim'] = Wholesale['TRIM_DESC']

# %%
Wholesale_cleaned['Mileage'] = Wholesale['ODOMETER']

# %%
Wholesale_cleaned['Date'] = pd.to_datetime(Wholesale['SOLD_DT_KEY'], format='%Y%m%d')

# %%
Wholesale_cleaned.shape
# Out:
# (1191471, 9)

# %%
Wholesale_cleaned.head()
# Out:
#        Key     Source                Vin  Year  Make      Trim   Model  \
# 0  5004514  wholesale  1FTEW1EF7GFD46982  2016  Ford    Lariat   F-150
# 1  5092247  wholesale  1FMCU0JD7HUB06187  2017  Ford  Titanium  Escape
# 2  5092247  wholesale  1FMCU0J98GUC56903  2016  Ford  Titanium  Escape
# 3  5420499  wholesale  1FADP3FE9HL274413  2017  Ford        SE   Focus
# 4  5177158  wholesale  1FT8W3DTXHEC60427  2017  Ford    Lariat   F-350
#
#     Mileage       Date
# 0   36524.0 2019-08-08
# 1   20970.0 2019-08-01
# 2   19531.0 2019-08-01
# 3   36482.0 2019-08-01
# 4  109622.0 2019-08-01

# %%
Wholesale_cleaned.to_csv("Wholesale_cleaned.csv",index=False,date_format='%Y-%m-%d')

# %%
ddc_listings = pd.read_csv('ddc_listings.csv')

# %%
ddc_listings.shape
# Out:
# (6057530, 19)

# %%
ddc_listings.head()
# Out:
#       svoc_id  isFD            dealercode                            domain  \
# 0  70705895.0   0.0   pinetreefordlincoln                  pinetreeford.com
# 1  67421021.0   0.0    walkerjonescdjcllc  walkerjoneschryslerjeepdodge.com
# 2  68834621.0   0.0  evansvillemercedesmb            evansvillemercedes.com
# 3  69421969.0   0.0        mileasubarusoa                   mileasubaru.com
# 4    574405.0   0.0            plazalexus                    plazalexus.com
#
#                  vin    vehiclemake    vehiclemodel  vehiclemodelyear  \
# 0  1FTEW1EP1KFC68443           Ford           F-150            2019.0
# 1  3C6TRVCG4JE157071            Ram  ProMaster 2500            2018.0
# 2  WDC0G8EB0LF687867  Mercedes-Benz         GLC 300            2020.0
# 3  JF1VA1A6XL9801603         Subaru             WRX            2020.0
# 4  WDC0G4KB7HF258245  Mercedes-Benz             GLC            2017.0
#
#   vehicletypestring vehiclebodystyle  chromestyleid  mpgcity  mpghighway  \
# ...

# %%
ddc_listings_cleaned = pd.DataFrame()

# %%
ddc_listings_cleaned['Key'] = ddc_listings['dealercode']

# %%
ddc_listings_cleaned['Source'] = 'ddc_listings'

# %%
ddc_listings_cleaned['Vin'] = ddc_listings['vin']

# %%
ddc_listings_cleaned['Year'] = ddc_listings['vehiclemodelyear'].astype(int)

# %%
ddc_listings_cleaned['Make'] = ddc_listings['vehiclemake']

# %%
ddc_listings_cleaned['Model'] = ddc_listings['vehiclemodel']

# %%
ddc_listings_cleaned['Trim'] = ddc_listings['vehiclebodystyle']

# %%
ddc_listings_cleaned['Mileage'] = ddc_listings['odometermiles']

# %%
ddc_listings_cleaned['Date'] = pd.to_datetime(ddc_listings['last_seen_datetime']).dt.date

# %%
ddc_listings_cleaned.head()
# Out:
#                     Key        Source                Vin  Year           Make  \
# 0   pinetreefordlincoln  ddc_listings  1FTEW1EP1KFC68443  2019           Ford
# 1    walkerjonescdjcllc  ddc_listings  3C6TRVCG4JE157071  2018            Ram
# 2  evansvillemercedesmb  ddc_listings  WDC0G8EB0LF687867  2020  Mercedes-Benz
# 3        mileasubarusoa  ddc_listings  JF1VA1A6XL9801603  2020         Subaru
# 4            plazalexus  ddc_listings  WDC0G4KB7HF258245  2017  Mercedes-Benz
#
#             Model       Trim  Mileage        Date
# 0           F-150      Truck      NaN  2019-10-31
# 1  ProMaster 2500  Cargo Van     11.0  2019-10-26
# 2         GLC 300        SUV      NaN  2019-10-28
# 3             WRX      Sedan      NaN  2019-10-31
# 4             GLC        SUV      NaN  2019-10-13

# %%
ddc_listings_cleaned.to_csv("ddc_listings_cleaned.csv",index=False,date_format='%Y-%m-%d')

# %%
atc_listings = pd.read_csv('atc_listings.csv')

# %%
atc_listings.head()
# Out:
#       CAR_ID  CUSTOMER_ID STOCK_ID                VIN     MAKE        MODEL  \
# 0  485750148        70042   P25088  1LN6L9RP0J5606615  Lincoln  Continental
# 1  492720575        83813    37230  JTJYARBZXK2125964    Lexus       NX 300
# 2  472773630     67878603    P2510  JN1BJ1CP3HW025765   Nissan  Rogue Sport
# 3  472773630     72394791    P2510  JN1BJ1CP3HW025765   Nissan  Rogue Sport
# 4  483058027      1359774   18-722  WMWXM5C5XF3A04636     MINI       Cooper
#
#    MODEL_YEAR       TRIM_NAME      BODYSTYLE  NEW_IND  CERTIFIED_IND  \
# 0        2018         Reserve          Sedan        0              1
# 1        2019             FWD  Sport Utility        1              0
# 2        2017              SL  Sport Utility        0              0
# 3        2017              SL  Sport Utility        0              1
# 4        2015  2-Door Hardtop      Hatchback        0              0
#
#    PRICE_NUM  MSRP_NUM  MILEAGE_NUM  SPOTLIGHT_IND  REDUCED_IND  SPECIAL_CNT  \
# ...

# %%
atc_listings.shape
# Out:
# (9215447, 31)

# %%
atc_listings_cleaned = pd.DataFrame()

# %%
atc_listings_cleaned['Key'] = atc_listings['CUSTOMER_ID']

# %%
atc_listings_cleaned['Source'] = 'atc_listings'

# %%
atc_listings_cleaned['Vin'] = atc_listings['VIN']

# %%
atc_listings_cleaned['Year'] = atc_listings['MODEL_YEAR']

# %%
atc_listings_cleaned['Make'] = atc_listings['MAKE']

# %%
atc_listings_cleaned['Model'] = atc_listings['MODEL']

# %%
atc_listings_cleaned['Trim'] = atc_listings['TRIM_NAME']

# %%
atc_listings_cleaned['Mileage'] = atc_listings['MILEAGE_NUM'].astype(float)

# %%
atc_listings_cleaned['Date'] = pd.to_datetime(atc_listings['SOURCE_CREATED_DATETIME']).dt.date

# %%
atc_listings_cleaned.head()
# Out:
#         Key        Source                Vin  Year     Make        Model  \
# 0     70042  atc_listings  1LN6L9RP0J5606615  2018  Lincoln  Continental
# 1     83813  atc_listings  JTJYARBZXK2125964  2019    Lexus       NX 300
# 2  67878603  atc_listings  JN1BJ1CP3HW025765  2017   Nissan  Rogue Sport
# 3  72394791  atc_listings  JN1BJ1CP3HW025765  2017   Nissan  Rogue Sport
# 4   1359774  atc_listings  WMWXM5C5XF3A04636  2015     MINI       Cooper
#
#              Trim  Mileage        Date
# 0         Reserve   5182.0  2019-08-07
# 1             FWD     30.0  2019-09-17
# 2              SL      8.0  2019-08-23
# 3              SL      8.0  2019-08-23
# 4  2-Door Hardtop  18156.0  2019-10-29

# %%
ddc_listings_cleaned.head()
# Out:
#                     Key        Source                Vin  Year           Make  \
# 0   pinetreefordlincoln  ddc_listings  1FTEW1EP1KFC68443  2019           Ford
# 1    walkerjonescdjcllc  ddc_listings  3C6TRVCG4JE157071  2018            Ram
# 2  evansvillemercedesmb  ddc_listings  WDC0G8EB0LF687867  2020  Mercedes-Benz
# 3        mileasubarusoa  ddc_listings  JF1VA1A6XL9801603  2020         Subaru
# 4            plazalexus  ddc_listings  WDC0G4KB7HF258245  2017  Mercedes-Benz
#
#             Model       Trim  Mileage        Date
# 0           F-150      Truck      NaN  2019-10-31
# 1  ProMaster 2500  Cargo Van     11.0  2019-10-26
# 2         GLC 300        SUV      NaN  2019-10-28
# 3             WRX      Sedan      NaN  2019-10-31
# 4             GLC        SUV      NaN  2019-10-13

# %%
Wholesale_cleaned.head()
# Out:
#        Key     Source                Vin  Year  Make   Model      Trim  \
# 0  5004514  wholesale  1FTEW1EF7GFD46982  2016  Ford   F-150    Lariat
# 1  5092247  wholesale  1FMCU0JD7HUB06187  2017  Ford  Escape  Titanium
# 2  5092247  wholesale  1FMCU0J98GUC56903  2016  Ford  Escape  Titanium
# 3  5420499  wholesale  1FADP3FE9HL274413  2017  Ford   Focus        SE
# 4  5177158  wholesale  1FT8W3DTXHEC60427  2017  Ford   F-350    Lariat
#
#     Mileage       Date
# 0   36524.0 2019-08-08
# 1   20970.0 2019-08-01
# 2   19531.0 2019-08-01
# 3   36482.0 2019-08-01
# 4  109622.0 2019-08-01

# %%
frank_merge = pd.concat([Wholesale_cleaned, atc_listings_cleaned, ddc_listings_cleaned], ignore_index=True)

# %%
frank_merge.shape
# Out:
# (16464448, 9)

# %%
frank_merge.describe()
# Out:
#                Year       Mileage
# count  1.646445e+07  1.169645e+07
# mean   2.016553e+03  3.773594e+04
# std    3.900636e+00  1.078850e+05
# min    1.916000e+03  0.000000e+00
# 25%    2.015000e+03  1.200000e+01
# 50%    2.018000e+03  2.382900e+04
# 75%    2.019000e+03  5.164300e+04
# max    2.020000e+03  2.987923e+08

# %%
frank_merge.isna().sum()
# Out:
# Key              0
# Source           0
# Vin             39
# Year             0
# Make         11700
# Model        18315
# Trim       1093962
# Mileage    4767995
# Date             0
# dtype: int64

# %%
frank_merge.to_csv("frank_merge.csv",index=False,date_format='%Y-%m-%d')

# %%
frank_merge = pd.read_csv("frank_merge.csv")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
frank_merge['Date']=pd.to_datetime(frank_merge['Date']).dt.date

# %%
frank_merge.head()
# Out:
#        Key     Source                Vin  Year  Make   Model      Trim  \
# 0  5004514  wholesale  1FTEW1EF7GFD46982  2016  Ford   F-150    Lariat
# 1  5092247  wholesale  1FMCU0JD7HUB06187  2017  Ford  Escape  Titanium
# 2  5092247  wholesale  1FMCU0J98GUC56903  2016  Ford  Escape  Titanium
# 3  5420499  wholesale  1FADP3FE9HL274413  2017  Ford   Focus        SE
# 4  5177158  wholesale  1FT8W3DTXHEC60427  2017  Ford   F-350    Lariat
#
#     Mileage        Date
# 0   36524.0  2019-08-08
# 1   20970.0  2019-08-01
# 2   19531.0  2019-08-01
# 3   36482.0  2019-08-01
# 4  109622.0  2019-08-01

# %%
JZ_merge = pd.read_csv("JZ_merge.csv")

# %%
polk_merge = pd.read_csv('polk_merge_new.csv')

# %%
carl_merge_1 = pd.DataFrame()
carl_merge_1['Key']=polk_merge['Key']
carl_merge_1['Source']=polk_merge['Source']
carl_merge_1['Vin']=polk_merge['Vin']
carl_merge_1['Year']=polk_merge['Year']
carl_merge_1['Make']=polk_merge['Make']
carl_merge_1['Model']=polk_merge['Model']
carl_merge_1['Trim']=polk_merge['Trim']
carl_merge_1['Mileage']=polk_merge['Mileage']
carl_merge_1['Date']=pd.to_datetime(polk_merge['Date']).dt.date

# %%
yp_merge = pd.read_csv('Carl_VAUTO_SOLD_MARKET_VEHICLE.csv')

# %%
carl_merge_1.head()
# Out:
#                  Key Source                Vin  Year    Make           Model  \
# 0  5TDDZ3DC0LS228496   polk  5TDDZ3DC0LS228496  2020  TOYOTA          SIENNA
# 1  KNMAT2MT9KP550612   polk  KNMAT2MT9KP550612  2019  NISSAN           ROGUE
# 2  5J6RW2H5XKL013495   polk  5J6RW2H5XKL013495  2019   HONDA            CR-V
# 3  1C4RJFBGXKC815499   polk  1C4RJFBGXKC815499  2019    JEEP  GRAND CHEROKEE
# 4  7FARW1H50KE021466   polk  7FARW1H50KE021466  2019   HONDA            CR-V
#
#   Trim  Mileage        Date
# 0  MTL   1504.0  2019-08-02
# 1  MTL      2.0  2019-08-02
# 2   EX     10.0  2019-08-02
# 3  LTD     11.0  2019-08-02
# 4   EX     25.0  2019-08-02

# %%
JZ_merge.head()
# Out:
#    Key            Source                Vin  Year  Make       Model  \
# 0    0  vauto_recent_new  1C6SRFFT4KN744751  2019   Ram        1500
# 1    1  vauto_recent_new  1FMJU1HT3KEA63995  2019  Ford  Expedition
# 2    2  vauto_recent_new  1FMSK8DH4LGA36038  2020  Ford    Explorer
# 3    3  vauto_recent_new  1FT7W2A6XKEF37170  2019  Ford     F-250SD
# 4    4  vauto_recent_new  1FTFW1RG2KFB68284  2019  Ford       F-150
#
#                  Trim  Mileage        Date
# 0  Big Horn/Lone Star      NaN  2019-09-27
# 1                 XLT      NaN  2019-08-29
# 2                 XLT     24.0  2019-10-07
# 3                  XL      4.0  2019-09-06
# 4              Raptor     12.0  2019-08-28

# %%
yp_merge.head()
# Out:
#    Key Source                Vin  Year    Make Model       Trim  Mileage  \
# 0    0   VASC  137PH90376E217503  2006  Hummer    H1  Open Top   12980.0
# 1    1   VASC  19UDE2F30HA009689  2017   Acura   ILX      2.4L   31319.0
# 2    2   VASC  19UDE2F37HA003470  2017   Acura   ILX      Base   36558.0
# 3    3   VASC  19UDE2F3XGA000304  2016   Acura   ILX      2.4L   47871.0
# 4    4   VASC  19UDE2F70HA004298  2017   Acura   ILX        NaN  10834.0
#
#          Date
# 0  2019-10-06
# 1  2019-09-27
# 2  2019-08-24
# 3  2019-10-24
# 4  2019-09-20

# %%
frank_merge.head()
# Out:
#        Key     Source                Vin  Year  Make   Model      Trim  \
# 0  5004514  wholesale  1FTEW1EF7GFD46982  2016  Ford   F-150    Lariat
# 1  5092247  wholesale  1FMCU0JD7HUB06187  2017  Ford  Escape  Titanium
# 2  5092247  wholesale  1FMCU0J98GUC56903  2016  Ford  Escape  Titanium
# 3  5420499  wholesale  1FADP3FE9HL274413  2017  Ford   Focus        SE
# 4  5177158  wholesale  1FT8W3DTXHEC60427  2017  Ford   F-350    Lariat
#
#     Mileage        Date
# 0   36524.0  2019-08-08
# 1   20970.0  2019-08-01
# 2   19531.0  2019-08-01
# 3   36482.0  2019-08-01
# 4  109622.0  2019-08-01

# %%
data_for_vma = pd.concat([frank_merge, carl_merge_1, yp_merge, JZ_merge], ignore_index=True)

# %%
data_for_vma.to_csv('data_for_vma.csv',index=False,date_format='%Y-%m-%d')

# %%
data_for_vma.to_csv('data_for_vma_pipe.csv',index=False,date_format='%Y-%m-%d',sep='|')

# %%
data_for_vma.shape
# Out:
# (32668869, 9)

# %%
frank_merge.shape
# Out:
# (16464448, 9)

# %%
JZ_merge.shape
# Out:
# (3913056, 9)

# %%
yp_merge.shape
# Out:
# (8875722, 9)

# %%
carl_merge_1.shape
# Out:
# (3415643, 9)

# %%
import boto3
s3 = boto3.resource('s3')

# %%
s3.meta.client.upload_file('data_for_vma_pipe.csv', 'cads-emory-data', 'data_for_vma_pipe.csv')

# %%
df = pd.read_csv("s3://cads-emory-data/data_for_vma_pipe.csv",sep="|")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#        Key     Source                Vin  Year  Make   Model      Trim  \
# 0  5004514  wholesale  1FTEW1EF7GFD46982  2016  Ford   F-150    Lariat
# 1  5092247  wholesale  1FMCU0JD7HUB06187  2017  Ford  Escape  Titanium
# 2  5092247  wholesale  1FMCU0J98GUC56903  2016  Ford  Escape  Titanium
# 3  5420499  wholesale  1FADP3FE9HL274413  2017  Ford   Focus        SE
# 4  5177158  wholesale  1FT8W3DTXHEC60427  2017  Ford   F-350    Lariat
#
#     Mileage        Date
# 0   36524.0  2019-08-08
# 1   20970.0  2019-08-01
# 2   19531.0  2019-08-01
# 3   36482.0  2019-08-01
# 4  109622.0  2019-08-01

# %%
df.shape
# Out:
# (32668869, 9)
