# %%
# !pip install numpy==1.15.1
# Out:
# ...
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install pyarrow==0.15.1
# Out:
# ...
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import pyarrow

# %%
data = pd.read_parquet('s3://cads-emory-data/data/parquet/vauto/vauto_atc_customer_xref/part-00000-e46ed1bc-b8cd-4b2d-9d80-02ecbfefcd31-c000.snappy.parquet')

# %%
data.shape
# Out:
# (375, 5)

# %%
data.head()
# Out:
#                  vauto_seller_name atc_customer_id  \
# 0    #1 BROOKVILLE CHEVROLET BUICK        56476876
# 1   #1 Cochran Hyundai South Hills        65575405
# 2  #1 Cochran Subaru of Butler Co.        69699141
# 3                    1st Rate Auto          498995
# 4                             6731          577765
#
#                     atc_customer_name                  atc_website_address  \
# 0       #1 Brookville Chevrolet Buick                                 null
# 1   #1 Cochran Hyundai of South Hills                      www.cochran.com
# 2  #1 Cochran Subaru of Butler County  http://www.cochransubarubutler.com/
# 3         Douglas Jeep Chrysler Dodge           http://www.douglasjeep.com
# 4        Larry H. Miller Honda Murray                     www.lhmhonda.com
#
#    vin_cnt
# 0        6
# 1        3
# 2       84
# 3        6
# 4        1

# %%
appended_data = []
for x in list(range(0, 200)):
    y = str(100000 + x)[-5:]
    print(y)
    filename = "s3://cads-emory-data/data/parquet/vauto/vauto_atc_customer_xref/part-" + y + "-e46ed1bc-b8cd-4b2d-9d80-02ecbfefcd31-c000.snappy.parquet"
    data = pd.read_parquet(filename)
    print(data.shape)
    # store DataFrame in list
    appended_data.append(data)
# see pd.concat documentation for more info
vauto_atc = pd.concat(appended_data)
# Out:
# 00000
# (375, 5)
# 00001
# (349, 5)
# 00002
# (418, 5)
# 00003
# (357, 5)
# 00004
# (383, 5)
# 00005
# (399, 5)
# 00006
# (362, 5)
# 00007
# (395, 5)
# 00008
# (378, 5)
# 00009
# (365, 5)
# 00010
# (361, 5)
# 00011
# (396, 5)
# 00012
# (375, 5)
# 00013
# (372, 5)
# 00014
# (350, 5)
# 00015
# (400, 5)
# 00016
# (376, 5)
# 00017
# (379, 5)
# 00018
# (345, 5)
# 00019
# (408, 5)
# 00020
# (327, 5)
# 00021
# (367, 5)
# 00022
# (373, 5)
# 00023
# (392, 5)
# 00024
# (402, 5)
# 00025
# (375, 5)
# 00026
# (409, 5)
# 00027
# (404, 5)
# 00028
# (415, 5)
# 00029
# (348, 5)
# 00030
# (371, 5)
# 00031
# (372, 5)
# 00032
# (391, 5)
# 00033
# (360, 5)
# 00034
# (360, 5)
# 00035
# (370, 5)
# 00036
# (362, 5)
# 00037
# (367, 5)
# 00038
# (378, 5)
# 00039
# (357, 5)
# 00040
# (382, 5)
# 00041
# (384, 5)
# 00042
# (372, 5)
# 00043
# (381, 5)
# 00044
# (394, 5)
# 00045
# (412, 5)
# 00046
# (378, 5)
# 00047
# (364, 5)
# 00048
# (373, 5)
# 00049
# (374, 5)
# 00050
# (341, 5)
# 00051
# (412, 5)
# 00052
# ...

# %%
vauto_atc.shape
# Out:
# (74680, 5)

# %%
vauto_atc.head(20)
# Out:
#                                     vauto_seller_name atc_customer_id  \
# 0                       #1 BROOKVILLE CHEVROLET BUICK        56476876
# 1                      #1 Cochran Hyundai South Hills        65575405
# 2                     #1 Cochran Subaru of Butler Co.        69699141
# 3                                       1st Rate Auto          498995
# 4                                                6731          577765
# 5                                   A1 Classic Motors           73423
# 6                                    ADDISON AUTOPLEX        70670925
# 7                                    AMIGO AUTO SALES         3274119
# 8                                        AUDI MODESTO        71857897
# 9                               AUDIA MOTOR GROUP LLC         1856627
# 10               AUTO EXPRESS FIAT ALFA ROMEO OF ERIE        68104133
# 11                                AUTO FINANCE CENTER        65757319
# ...

# %%
vauto_atc.to_csv("vauto_atc_customer_xref.csv",index=False)
