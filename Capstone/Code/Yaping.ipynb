# %%
import pandas as pd

# %%
vma = pd.read_csv('vma.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
vma.head()
# Out:
#        Key     Source                Vin  Year  Make   Model      Trim  \
# 0  5004514  wholesale  1FTEW1EF7GFD46982  2016  Ford   F-150    Lariat
# 1  5092247  wholesale  1FMCU0JD7HUB06187  2017  Ford  Escape  Titanium
# 2  5092247  wholesale  1FMCU0J98GUC56903  2016  Ford  Escape  Titanium
# 3  5420499  wholesale  1FADP3FE9HL274413  2017  Ford   Focus        SE
# 4  5177158  wholesale  1FT8W3DTXHEC60427  2017  Ford   F-350    Lariat
#
#     Mileage        Date MIDMapAlgorithm  ...  RMI_adj_current AvgPrice  \
# 0   36524.0  2019-08-08           Exact  ...          33600.0  26395.0
# 1   20970.0  2019-08-01           Exact  ...          18600.0  14428.0
# 2   19531.0  2019-08-01           Exact  ...          17950.0  13638.0
# 3   36482.0  2019-08-01           Exact  ...          10950.0  10469.0
# 4  109622.0  2019-08-01           Exact  ...          43200.0  45758.0
#
#    avgmiles  Velocity  Salesefficiency  AvgDaysToSell vol_tier  availability  \
# ...

# %%
vma.shape
# Out:
# (32668869, 23)

# %%
vma.Source.unique()
# Out:
# array(['wholesale', 'atc_listi', 'ddc_listi', 'polk', 'VASC', 'VASNC',
#        'vauto_rec'], dtype=object)

# %%
mask =vma['Source']=='polk'
vma[mask].shape
# Out:
# (3415643, 23)

# %%
vma_polk=vma.loc[vma['Source']=='polk']

# %%
vma_polk.shape
# Out:
# (3415643, 23)

# %%
Polk= pd.read_csv("polk_data_clean.csv")
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Polk.columns
# Out:
# Index(['data_type', 'vin', 'polk_con_num', 'dealer_name', 'dealer_address',
#        'dealer_town', 'dealer_state', 'dealer_zip', 'dealer_dma',
#        'dealer_fran_ind', 'vin_year_model', 'segment', 'make', 'model',
#        'series', 'sub_series', 'vehicle_type', 'body_style', 'cylinders',
#        'drive_type', 'doors', 'fuel_type', 'orgin', 'gvw', 'bed_size',
#        'cab_size', 'turbo', 'financial_inst', 'veh_mfg_base_list_price',
#        'corporation', 'reg_dma', 'reg_state', 'reg_county', 'reg_zip',
#        'reg_type', 'purchase_lease', 'report_year_month', 'transaction_date',
#        'mileage', 'trans_price', 'age', 'income', 'gender', 'ethnic_group',
#        'sub_ethnic_group', 'language', 'reg_type_code', 'new_count'],
#       dtype='object')

# %%
Polk=Polk.loc[:,['vin', 'polk_con_num','dealer_name','purchase_lease','transaction_date','trans_price']]

# %%
mask = (Polk['transaction_date'] > '2019-08-01') & (Polk['transaction_date'] <= '2019-10-31')
Polk = Polk.loc[mask]

# %%
Polk.shape
# Out:
# (3415643, 6)

# %%
p= pd.read_csv("polk_merge_new.csv")

# %%
Polk_m = pd.read_csv("PolkCAMatch_2017_02_FEB_v4.csv")
pd.set_option('display.max_columns', None)

# %%
p.columns
# Out:
# Index(['Unnamed: 0', 'Key', 'Source', 'Vin', 'Year', 'Make', 'Model', 'Trim',
#        'Mileage', 'Date'],
#       dtype='object')

# %%
Polk.columns
# Out:
# Index(['vin', 'polk_con_num', 'dealer_name', 'purchase_lease',
#        'transaction_date', 'trans_price'],
#       dtype='object')

# %%
Polk_new = pd.merge(Polk, p, how='right', left_on=['vin'], right_on = ['Vin'])

# %%
Polk_new.shape
# Out:
# (3415643, 16)

# %%
Polk_new.columns
# Out:
# Index(['vin', 'polk_con_num', 'dealer_name', 'purchase_lease',
#        'transaction_date', 'trans_price', 'Unnamed: 0', 'Key', 'Source', 'Vin',
#        'Year', 'Make', 'Model', 'Trim', 'Mileage', 'Date'],
#       dtype='object')

# %%
Polk_new=Polk_new.loc[:,['Vin','polk_con_num','dealer_name', 'purchase_lease',
       'trans_price']]

# %%
Polk_new.head()
# Out:
#                  Vin  polk_con_num                   dealer_name  \
# 0  5TDDZ3DC0LS228496        7068.0           TOYOTA OF WATERTOWN
# 1  KNMAT2MT9KP550612       19923.0                 COGGIN NISSAN
# 2  5J6RW2H5XKL013495       18049.0             ED NAPLETON HONDA
# 3  1C4RJFBGXKC815499       22221.0  FLETCHER CHRYSLER DODGE JEEP
# 4  7FARW1H50KE021466       23597.0  AUTONATION HONDA MIAMI LAKES
#
#   purchase_lease  trans_price
# 0       RET-Loan          NaN
# 1       RET-Loan          NaN
# 2       RET-Loan          NaN
# 3       RET-Loan          NaN
# 4      RET-Lease          NaN

# %%
Polk_m.columns
# Out:
# Index(['associationid', 'polk_id', 'polk_sourcecode', 'name', 'address',
#        'city', 'state', 'zip', 'countrycode', 'ca_id', 'ca_sourcecode',
#        'cust_name', 'c_addr_line_1', 'c_city', 'c_province_cd', 'c_postal_cd',
#        'c_zipext', 'c_countrycode'],
#       dtype='object')

# %%
Polk_m.head()
# Out:
#    associationid  polk_id polk_sourcecode                    name  \
# 0         171662      3.0            POLK  RIPLEY & FLETCHER FORD
# 1         186291     25.0            POLK    CHUCK RENZE FORD LLC
# 2         196131     30.0            POLK  PUNDMANN MOTOR COMPANY
# 3         111403     36.0            POLK         DAWSON MOTOR CO
# 4          15562     41.0            POLK        RANDALL FORD INC
#
#               address           city state    zip countrycode       ca_id  \
# 0          80 MAIN ST    SOUTH PARIS    ME   4281         USA  CA11213526
# 1  751 E LAKESHORE DR     MANISTIQUE    MI  49854         USA  CA11219684
# 2      2727 W CLAY ST  SAINT CHARLES    MO  63301         USA  CA11239151
# 3       255 N MAIN ST         DAWSON    GA  39842         USA  CA11379356
# 4     5500 ROGERS AVE     FORT SMITH    AR  72903         USA  CA11269698
#
#   ca_sourcecode               cust_name       c_addr_line_1         c_city  \
# ...

# %%
len(Polk_m.associationid.unique())
# Out:
# 67755

# %%
len(Polk_m.polk_id.unique())
# Out:
# 69018

# %%
len(Polk_m.ca_id.unique())
# Out:
# 67755

# %%
vma_polk.columns
# Out:
# Index(['Key', 'Source', 'Vin', 'Year', 'Make', 'Model', 'Trim', 'Mileage',
#        'Date', 'MIDMapAlgorithm', 'mid15', 'VPID', 'MMR_adj_current',
#        'RMI_adj_current', 'AvgPrice', 'avgmiles', 'Velocity',
#        'Salesefficiency', 'AvgDaysToSell', 'vol_tier', 'availability',
#        'inventory', 'spread_current'],
#       dtype='object')

# %%
vma_polk.head()
# Out:
#                   Key Source                Vin  Year    Make           Model  \
# 16464448  5TDDZ3DC0LS   polk  5TDDZ3DC0LS228496  2020  TOYOTA          SIENNA
# 16464449  KNMAT2MT9KP   polk  KNMAT2MT9KP550612  2019  NISSAN           ROGUE
# 16464450  5J6RW2H5XKL   polk  5J6RW2H5XKL013495  2019   HONDA            CR-V
# 16464451  1C4RJFBGXKC   polk  1C4RJFBGXKC815499  2019    JEEP  GRAND CHEROKEE
# 16464452  7FARW1H50KE   polk  7FARW1H50KE021466  2019   HONDA            CR-V
#
#          Trim  Mileage        Date MIDMapAlgorithm         mid15  \
# 16464448  MTL   1504.0  2019-08-02           Exact  2.020050e+14
# 16464449  MTL      2.0  2019-08-02           Exact  2.019056e+14
# 16464450   EX     10.0  2019-08-02           Exact  2.019023e+14
# 16464451  LTD     11.0  2019-08-02         Popular  2.019028e+14
# 16464452   EX     25.0  2019-08-02           Exact  2.019024e+14
#
#                               VPID  MMR_adj_current  RMI_adj_current  \
# ...

# %%
Polk_new.shape
# Out:
# (3415643, 5)

# %%
df = pd.merge(Polk_new, vma_polk,  how='right', left_on=['Vin'], right_on = ['Vin'])

# %%
df.shape
# Out:
# (3415643, 27)

# %%
df.columns
# Out:
# Index(['Vin', 'polk_con_num', 'dealer_name', 'purchase_lease', 'trans_price',
#        'Key', 'Source', 'Year', 'Make', 'Model', 'Trim', 'Mileage', 'Date',
#        'MIDMapAlgorithm', 'mid15', 'VPID', 'MMR_adj_current',
#        'RMI_adj_current', 'AvgPrice', 'avgmiles', 'Velocity',
#        'Salesefficiency', 'AvgDaysToSell', 'vol_tier', 'availability',
#        'inventory', 'spread_current'],
#       dtype='object')

# %%
df['polk_con_num'] = pd.to_numeric(df['polk_con_num'], errors='coerce')
df.head()
# Out:
#                  Vin  polk_con_num                   dealer_name  \
# 0  5TDDZ3DC0LS228496        7068.0           TOYOTA OF WATERTOWN
# 1  KNMAT2MT9KP550612       19923.0                 COGGIN NISSAN
# 2  5J6RW2H5XKL013495       18049.0             ED NAPLETON HONDA
# 3  1C4RJFBGXKC815499       22221.0  FLETCHER CHRYSLER DODGE JEEP
# 4  7FARW1H50KE021466       23597.0  AUTONATION HONDA MIAMI LAKES
#
#   purchase_lease  trans_price          Key Source  Year    Make  \
# 0       RET-Loan          NaN  5TDDZ3DC0LS   polk  2020  TOYOTA
# 1       RET-Loan          NaN  KNMAT2MT9KP   polk  2019  NISSAN
# 2       RET-Loan          NaN  5J6RW2H5XKL   polk  2019   HONDA
# 3       RET-Loan          NaN  1C4RJFBGXKC   polk  2019    JEEP
# 4      RET-Lease          NaN  7FARW1H50KE   polk  2019   HONDA
#
#             Model Trim  Mileage        Date MIDMapAlgorithm         mid15  \
# 0          SIENNA  MTL   1504.0  2019-08-02           Exact  2.020050e+14
# ...

# %%
Polk_m['polk_id'] = Polk_m['polk_id'].astype(float)

# %%
Polk_m.head()
# Out:
#    associationid  polk_id polk_sourcecode                    name  \
# 0         171662      3.0            POLK  RIPLEY & FLETCHER FORD
# 1         186291     25.0            POLK    CHUCK RENZE FORD LLC
# 2         196131     30.0            POLK  PUNDMANN MOTOR COMPANY
# 3         111403     36.0            POLK         DAWSON MOTOR CO
# 4          15562     41.0            POLK        RANDALL FORD INC
#
#               address           city state    zip countrycode       ca_id  \
# 0          80 MAIN ST    SOUTH PARIS    ME   4281         USA  CA11213526
# 1  751 E LAKESHORE DR     MANISTIQUE    MI  49854         USA  CA11219684
# 2      2727 W CLAY ST  SAINT CHARLES    MO  63301         USA  CA11239151
# 3       255 N MAIN ST         DAWSON    GA  39842         USA  CA11379356
# 4     5500 ROGERS AVE     FORT SMITH    AR  72903         USA  CA11269698
#
#   ca_sourcecode               cust_name       c_addr_line_1         c_city  \
# ...

# %%
len(df.dealer_name.unique())
# Out:
# 18640

# %%
len(Polk_m.name.unique())
# Out:
# 60981

# %%
max(Polk_m.polk_id.unique())
# Out:
# 412143.0

# %%
max(df.polk_con_num.unique())
# Out:
# 467101.0

# %%
mylist = list(set(df.polk_con_num.unique()))

# %%
mylist_m = list(set(Polk_m.polk_id.unique()))

# %%
sum(map(lambda each: each in mylist_m, mylist))
# Out:
# 15200

# %%
S1 = set(mylist)
S2 = set(mylist_m)
len(S1.intersection(S2))
# Out:
# 15200

# %%
match = pd.merge(df, Polk_m, left_on=['polk_con_num'], right_on=['polk_id'],how='left')

# %%
match.shape
# Out:
# (3415643, 45)

# %%
match.head()
# Out:
#                  Vin  polk_con_num                   dealer_name  \
# 0  5TDDZ3DC0LS228496        7068.0           TOYOTA OF WATERTOWN
# 1  KNMAT2MT9KP550612       19923.0                 COGGIN NISSAN
# 2  5J6RW2H5XKL013495       18049.0             ED NAPLETON HONDA
# 3  1C4RJFBGXKC815499       22221.0  FLETCHER CHRYSLER DODGE JEEP
# 4  7FARW1H50KE021466       23597.0  AUTONATION HONDA MIAMI LAKES
#
#   purchase_lease  trans_price          Key Source  Year    Make  \
# 0       RET-Loan          NaN  5TDDZ3DC0LS   polk  2020  TOYOTA
# 1       RET-Loan          NaN  KNMAT2MT9KP   polk  2019  NISSAN
# 2       RET-Loan          NaN  5J6RW2H5XKL   polk  2019   HONDA
# 3       RET-Loan          NaN  1C4RJFBGXKC   polk  2019    JEEP
# 4      RET-Lease          NaN  7FARW1H50KE   polk  2019   HONDA
#
#             Model Trim  Mileage        Date MIDMapAlgorithm         mid15  \
# 0          SIENNA  MTL   1504.0  2019-08-02           Exact  2.020050e+14
# ...

# %%
df.shape
# Out:
# (3415643, 27)

# %%
df.isna().sum()
# Out:
# Vin                      0
# polk_con_num        233714
# dealer_name              0
# purchase_lease           0
# trans_price        2286433
# Key                      0
# Source                   0
# Year                     0
# Make                     0
# Model                    0
# Trim                123633
# Mileage             709131
# Date                     0
# MIDMapAlgorithm          0
# mid15                12284
# VPID                 28972
# MMR_adj_current     731769
# RMI_adj_current     569770
# AvgPrice            177839
# avgmiles            177839
# Velocity            292433
# Salesefficiency     177967
# AvgDaysToSell       177839
# vol_tier            177839
# availability        177839
# inventory           179232
# spread_current      877204
# dtype: int64

# %%
match_new.isna().sum()
# Out:
# ca_id               730806
# Vin                      0
# Year                     0
# Make                     0
# Model                    0
# Trim                123633
# Mileage             709131
# Date                     0
# MIDMapAlgorithm          0
# mid15                12284
# VPID                 28972
# MMR_adj_current     731769
# RMI_adj_current     569770
# AvgPrice            177839
# avgmiles            177839
# Velocity            292433
# Salesefficiency     177967
# AvgDaysToSell       177839
# vol_tier            177839
# availability        177839
# inventory           179232
# spread_current      877204
# polk_con_num        233714
# dealer_name              0
# purchase_lease           0
# trans_price        2286433
# dtype: int64

# %%
match.columns
# Out:
# Index(['Vin', 'polk_con_num', 'dealer_name', 'purchase_lease', 'trans_price',
#        'Key', 'Source', 'Year', 'Make', 'Model', 'Trim', 'Mileage', 'Date',
#        'MIDMapAlgorithm', 'mid15', 'VPID', 'MMR_adj_current',
#        'RMI_adj_current', 'AvgPrice', 'avgmiles', 'Velocity',
#        'Salesefficiency', 'AvgDaysToSell', 'vol_tier', 'availability',
#        'inventory', 'spread_current', 'associationid', 'polk_id',
#        'polk_sourcecode', 'name', 'address', 'city', 'state', 'zip',
#        'countrycode', 'ca_id', 'ca_sourcecode', 'cust_name', 'c_addr_line_1',
#        'c_city', 'c_province_cd', 'c_postal_cd', 'c_zipext', 'c_countrycode'],
#       dtype='object')

# %%
match_new=match.loc[:,['ca_id', 'Vin', 'Year', 'Make', 'Model', 'Trim', 'Mileage',
       'Date', 'MIDMapAlgorithm', 'mid15', 'VPID', 'MMR_adj_current',
       'RMI_adj_current', 'AvgPrice', 'avgmiles', 'Velocity',
       'Salesefficiency', 'AvgDaysToSell', 'vol_tier', 'availability',
       'inventory', 'spread_current', 'polk_con_num', 'dealer_name','purchase_lease','trans_price']]

# %%
match_new.head()
# Out:
#         ca_id                Vin  Year    Make           Model Trim  Mileage  \
# 0         NaN  5TDDZ3DC0LS228496  2020  TOYOTA          SIENNA  MTL   1504.0
# 1  CA11220092  KNMAT2MT9KP550612  2019  NISSAN           ROGUE  MTL      2.0
# 2         NaN  5J6RW2H5XKL013495  2019   HONDA            CR-V   EX     10.0
# 3  CA11274812  1C4RJFBGXKC815499  2019    JEEP  GRAND CHEROKEE  LTD     11.0
# 4  CA11207450  7FARW1H50KE021466  2019   HONDA            CR-V   EX     25.0
#
#          Date MIDMapAlgorithm         mid15                      VPID  \
# 0  2019-08-02           Exact  2.020050e+14        2020_Toyota_Sienna
# 1  2019-08-02           Exact  2.019056e+14         2019_Nissan_Rogue
# 2  2019-08-02           Exact  2.019023e+14           2019_Honda_CR-V
# 3  2019-08-02         Popular  2.019028e+14  2019_Jeep_Grand Cherokee
# 4  2019-08-02           Exact  2.019024e+14           2019_Honda_CR-V
#
#    MMR_adj_current  RMI_adj_current  AvgPrice  avgmiles Velocity  \
# ...

# %%
match_new.to_csv('polk_322.csv')

# %%
len(match_new.polk_con_num.unique())
# Out:
# 19389

# %%
len(match_new.dealer_name.unique())
# Out:
# 18640

# %%
len(match_new.ca_id.unique())
# Out:
# 15088

# %%
client_master = pd.read_csv("client_master.csv")

# %%
client_master.head(20)
# Out:
#         acctnum accttype acctsubtype        caid                   custname  \
# 0   DETA7000403      OVC     AUCTION  CA11741570    GARY L HAZELLIEF/PUBLIC
# 1   AREN7000438      OVC     AUCTION  CA11740438                ARSALAN ALI
# 2   ALOH7001395      OVC     AUCTION  CA11747260                GARY OSHIRO
# 3         80506      NGC      DEALER  CA11346933            BAVARIAN MOTORS
# 4       5224772      OVC     AUCTION  CA11465278       JETT AUCTION LIMITED
# 5   OAA 7024585      OVC     AUCTION  CA11756287             WILFREDO COLON
# 6       5099679      OVC     AUCTION  CA11661885          SPORTS AUTO SALES
# 7   OAA 7008152      OVC     AUCTION  CA11754476         CYNTHIA S LEMASTER
# 8   OAA 7025310      OVC     AUCTION  CA11756152         JOHN R MATTHEWS 11
# 9   DADE7000623      OVC     AUCTION  CA11739863             MICHAEL BRIGGS
# 10  ALBA7003123      OVC     AUCTION  CA11751211              REUBEN J PECK
# ...

# %%
client_master.columns
# Out:
# Index(['acctnum', 'accttype', 'acctsubtype', 'caid', 'custname', 'custcity',
#        'custaddrline1', 'custprovincecode', 'custpostalcode', 'externalidtype',
#        'externalid', 'acctaddline1', 'acctcity', 'acctprovincecd',
#        'acctpostalcd'],
#       dtype='object')
