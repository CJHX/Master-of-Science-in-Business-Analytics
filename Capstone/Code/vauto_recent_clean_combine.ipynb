# %%
import numpy as np
import pandas as pd

# %%
VNC = pd.read_csv('vauto_recent_market_data_new_clean.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
VNC.shape
# Out:
# (1671289, 43)

# %%
VNC.head()
# Out:
#                  vin postal_code stock_number  model_year  make       model  \
# 0  1C6SRFFT4KN744751       30474          NaN        2019   Ram        1500
# 1  1FMJU1HT3KEA63995       32124      DTK0221        2019  Ford  Expedition
# 2  1FMSK8DH4LGA36038       53813         3400        2020  Ford    Explorer
# 3  1FT7W2A6XKEF37170       33030     KEF37170        2019  Ford     F-250SD
# 4  1FTFW1RG2KFB68284       78539       191194        2019  Ford       F-150
#
#                series series_detail  odometer new_used  ...     created  \
# 0  Big Horn/Lone Star           NaN       NaN        N  ...  2019-02-24
# 1                 XLT           NaN       NaN        N  ...  2019-08-01
# 2                 XLT           NaN      24.0        N  ...  2019-08-03
# 3                  XL           NaN       4.0        N  ...  2019-06-26
# 4              Raptor           NaN      12.0        N  ...  2019-04-05
#
#     last_seen  list_price FIRST_LIST_PRICE MIN_LIST_PRICE  \
# ...

# %%
VNC.groupby('vin').count()[['stock_number','last_seen']].sort_values(['last_seen'],ascending=False).head()
# Out:
#                    stock_number  last_seen
# vin
# 2GNAXJEV6K6281653             2          2
# 1GCRWAEH6KZ390028             2          2
# 2T3H1RFV0KW037152             2          2
# 1GKKNKLA2KZ223279             2          2
# 3N1CP5CU0KL531664             2          2

# %%
VNC_17 = VNC[VNC.vin.str.len() == 17]

# %%
VNC_17.shape
# Out:
# (1670951, 43)

# %%
pd.set_option('display.max_columns', None)
VNC_17.head()
# Out:
#                  vin postal_code stock_number  model_year  make       model  \
# 0  1C6SRFFT4KN744751       30474          NaN        2019   Ram        1500
# 1  1FMJU1HT3KEA63995       32124      DTK0221        2019  Ford  Expedition
# 2  1FMSK8DH4LGA36038       53813         3400        2020  Ford    Explorer
# 3  1FT7W2A6XKEF37170       33030     KEF37170        2019  Ford     F-250SD
# 4  1FTFW1RG2KFB68284       78539       191194        2019  Ford       F-150
#
#                series series_detail  odometer new_used  body_description  \
# 0  Big Horn/Lone Star           NaN       NaN        N       4D Crew Cab
# 1                 XLT           NaN       NaN        N  4D Sport Utility
# 2                 XLT           NaN      24.0        N  4D Sport Utility
# 3                  XL           NaN       4.0        N       4D Crew Cab
# 4              Raptor           NaN      12.0        N      4D SuperCrew
#
# ...

# %%
VNC_17['postal_code'] = VNC_17['postal_code'].astype('str').str.strip()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
VNC_17.loc[(VNC_17.postal_code.str.len() != 5),'postal_code'] = np.nan
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
VNC_17[VNC_17.postal_code.str.len() == 5]
# Out:
#                        vin postal_code stock_number  model_year  \
# 0        1C6SRFFT4KN744751       30474          NaN        2019
# 1        1FMJU1HT3KEA63995       32124      DTK0221        2019
# 2        1FMSK8DH4LGA36038       53813         3400        2020
# 3        1FT7W2A6XKEF37170       33030     KEF37170        2019
# 4        1FTFW1RG2KFB68284       78539       191194        2019
# 5        1G1BE5SM7K7105984       78130       105984        2019
# 6        1G1JF6SB2K4144626       76206       293714        2019
# 7        1GNERJKW7LJ124095       32164        L0038        2020
# 8        1GT19ME76LF141986       83687      D400017        2020
# 9        1GYKNDRS8KZ197028       48375        9T687        2019
# 10       1HGCV1F35KA076768       91340      H194984        2019
# 11       1N4AZ1CP3KC317366       91345        N1148        2019
# 12       2C3CDXGJ5KH622153       30122          NaN        2019
# 13       2GNAXJEV2L6118757       48184      O118757        2020
# ...

# %%
VNC_17.model_year.unique()
# Out:
# array([2019, 2020, 2018, 2017, 2016, 2015])

# %%
sum(VNC_17.model_year.isna())
# Out:
# 0

# %%
sum(VNC_17.odometer.isna())
# Out:
# 530043

# %%
np.max(VNC_17.odometer)
# Out:
# 142142.0

# %%
VNC_17.new_used.unique()
# Out:
# array(['N'], dtype=object)

# %%
VNC_17.body_type.unique()
# Out:
# array(['Truck', 'SUV', 'Sedan', 'Hatchback', 'Wagon', 'Utility',
#        'Cargo Van', 'Coupe', 'Minivan/Van', 'Convertible', 'Cab/Chassis',
#        'Car (Passenger Vehic', 'Cutaway Van', nan, 'Trailer'],
#       dtype=object)

# %%
VNC_17.body_door_count.unique()
# Out:
# array([ 4.,  5.,  2.,  3., nan])

# %%
VNC_17.body_cab_style.unique()
# Out:
# array(['Crew Cab', nan, 'Passenger Van', 'Wagon', 'Extended Cab',
#        'Standard Cab', 'Cargo Van', 'Extended Cargo Van', 'Mega Cab',
#        'Extended Wagon'], dtype=object)

# %%
VNC_17.body_bed_style.unique()
# Out:
# array(['Short Bed', nan, 'Long Bed', 'Standard Bed', '5 ft', 'Long bed'],
#       dtype=object)

# %%
VNC_17.columns
# Out:
# Index(['vin', 'postal_code', 'stock_number', 'model_year', 'make', 'model',
#        'series', 'series_detail', 'odometer', 'new_used', 'body_description',
#        'body_type', 'body_door_count', 'body_cab_style', 'body_bed_style',
#        'body_roof_style', 'engine_description', 'engine_cylinder_count',
#        'engine_displacement', 'engine_fuel_type', 'transmission_description',
#        'transmission_type', 'transmission_gear_count', 'drive_train_type',
#        'exterior_color', 'exterior_base_color', 'interior_description',
#        'interior_color', 'interior_material', 'categorized_equipment_ids',
#        'days_ininventory', 'veh_segment', 'veh_type', 'created', 'last_seen',
#        'list_price', 'FIRST_LIST_PRICE', 'MIN_LIST_PRICE', 'seller_name',
#        'Currently_Active_IND', 'EFFECTIVE_START_TS', 'EFFECTIVE_END_TS',
#        'LATEST_VERSION_IND'],
#       dtype='object')

# %%
VNC_17.body_roof_style.unique()
# Out:
# array([nan, 'HardTop', 'Convertible', 'SoftTop', 'Targa'], dtype=object)

# %%
VNC_17['date'] = pd.to_datetime(VNC_17.EFFECTIVE_START_TS, format='%Y-%m-%d %H:%M:%S.%f')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
VNC_17['source'] = 'vauto_recent_new'
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
VNC_17['key'] = VNC_17.index
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
VMA_vauto_recent_new = VNC_17[['key','source','vin','model_year','make','model','series','odometer','date']]

# %%
VMA_vauto_recent_new.head()
# Out:
#    key            source                vin  model_year  make       model  \
# 0    0  vauto_recent_new  1C6SRFFT4KN744751        2019   Ram        1500
# 1    1  vauto_recent_new  1FMJU1HT3KEA63995        2019  Ford  Expedition
# 2    2  vauto_recent_new  1FMSK8DH4LGA36038        2020  Ford    Explorer
# 3    3  vauto_recent_new  1FT7W2A6XKEF37170        2019  Ford     F-250SD
# 4    4  vauto_recent_new  1FTFW1RG2KFB68284        2019  Ford       F-150
#
#                series  odometer       date
# 0  Big Horn/Lone Star       NaN 2019-09-27
# 1                 XLT       NaN 2019-08-29
# 2                 XLT      24.0 2019-10-07
# 3                  XL       4.0 2019-09-06
# 4              Raptor      12.0 2019-08-28

# %%
VMA_vauto_recent_new = VMA_vauto_recent_new.rename(columns={'key':'Key','source':'Source','vin':'Vin','model_year':'Year','make':'Make','model':'Model','series':'Trim','odometer':'Mileage','date':'Date'})

# %%
VMA_vauto_recent_new.head()
# Out:
#    Key            Source                Vin  Year  Make       Model  \
# 0    0  vauto_recent_new  1C6SRFFT4KN744751  2019   Ram        1500
# 1    1  vauto_recent_new  1FMJU1HT3KEA63995  2019  Ford  Expedition
# 2    2  vauto_recent_new  1FMSK8DH4LGA36038  2020  Ford    Explorer
# 3    3  vauto_recent_new  1FT7W2A6XKEF37170  2019  Ford     F-250SD
# 4    4  vauto_recent_new  1FTFW1RG2KFB68284  2019  Ford       F-150
#
#                  Trim  Mileage       Date
# 0  Big Horn/Lone Star      NaN 2019-09-27
# 1                 XLT      NaN 2019-08-29
# 2                 XLT     24.0 2019-10-07
# 3                  XL      4.0 2019-09-06
# 4              Raptor     12.0 2019-08-28

# %%
VMA_vauto_recent_new.to_csv("VMA_vauto_recent_new.csv",index=False)

# %%
vn = pd.read_csv('vauto_recent_market_data_clean.csv')
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
VNC = vn

# %%
VNC_17 = VNC[VNC.vin.str.len() == 17]

# %%
vn.shape
# Out:
# (2242344, 44)

# %%
VNC_17.shape
# Out:
# (2242105, 44)

# %%
VNC_17['postal_code'] = VNC_17['postal_code'].astype('str').str.strip()
VNC_17.loc[(VNC_17.postal_code.str.len() != 5),'postal_code'] = np.nan
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
VNC_17[VNC_17.postal_code.str.len() == 5]
# Out:
#                        vin postal_code stock_number  model_year  \
# 0        19XFC2F74GE058406       64114       9976HP        2016
# 1        1C4AJWAG5FL553038       95603          NaN        2015
# 2        1C4PJLCB1GW319991       81303        U3309        2016
# 3        1C4PJMAB4EW141130       44092      M19566A        2014
# 4        1C4PJMDX0KD379393       03801      JG1660A        2019
# 5        1FAHP2J86JG128613       48114        P5566        2018
# 6        1FMCU04152KA52473       65616       P7615B        2002
# 7        1FTEW1EP0HFB51039       29118        U7195        2017
# 8        1FTFW1CF9BFD27107       77505       80995A        2011
# 9        1FTPW14504KA84520       61615       50818K        2004
# 10       1FTRF12248KE91649       32926       19592A        2008
# 11       1G1AF1F50A7171120       55992       39051B        2010
# 12       1G1PE5SB6F7170335       75751       170335        2015
# 13       1G1ZD5ST0KF148626       63011      V990770        2019
# ...

# %%
VNC_17.model_year.unique()
# Out:
# array([2016, 2015, 2014, 2019, 2018, 2002, 2017, 2011, 2004, 2008, 2010,
#        2006, 2013, 2007, 2012, 2005, 2009, 2003, 1999, 1997, 1998, 2001,
#        2000, 1995, 1996, 2020, 1992, 1994, 1993, 1984])

# %%
VNC_17.new_used.unique()
# Out:
# array(['U'], dtype=object)

# %%
VNC_17['date'] = pd.to_datetime(VNC_17.EFFECTIVE_START_TS, format='%Y-%m-%d %H:%M:%S.%f')
VNC_17['source'] = 'vauto_recent_used'
VNC_17['key'] = VNC_17.index
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
VMA_vauto_recent_used = VNC_17[['key','source','vin','model_year','make','model','series','odometer','date']]
VMA_vauto_recent_used = VMA_vauto_recent_used.rename(columns={'key':'Key','source':'Source','vin':'Vin','model_year':'Year','make':'Make','model':'Model','series':'Trim','odometer':'Mileage','date':'Date'})

# %%
VMA_vauto_recent_used.head()
# Out:
#    Key             Source                Vin  Year   Make     Model      Trim  \
# 0    0  vauto_recent_used  19XFC2F74GE058406  2016  Honda     Civic        EX
# 1    1  vauto_recent_used  1C4AJWAG5FL553038  2015   Jeep  Wrangler     Sport
# 2    2  vauto_recent_used  1C4PJLCB1GW319991  2016   Jeep  Cherokee  Latitude
# 3    3  vauto_recent_used  1C4PJMAB4EW141130  2014   Jeep  Cherokee     Sport
# 4    4  vauto_recent_used  1C4PJMDX0KD379393  2019   Jeep  Cherokee   Limited
#
#    Mileage       Date
# 0  41218.0 2019-10-05
# 1  53415.0 2019-08-03
# 2  28189.0 2019-10-13
# 3  69167.0 2019-08-15
# 4   3060.0 2019-09-02

# %%
VMA_vauto_recent_used.shape
# Out:
# (2242105, 9)

# %%
VMA_vauto_recent_used.to_csv("VMA_vauto_recent_used.csv",index=False)

# %%
new = pd.read_csv('VMA_vauto_recent_new.csv')
used = pd.read_csv('VMA_vauto_recent_used.csv')

# %%
print(new.shape)
new.head()
# Out:
# (1670951, 9)
#    Key            Source                Vin  Year  Make       Model  \
# 0    0  vauto_recent_new  1C6SRFFT4KN744751  2019   Ram        1500
# 1    1  vauto_recent_new  1FMJU1HT3KEA63995  2019  Ford  Expedition
# 2    2  vauto_recent_new  1FMSK8DH4LGA36038  2020  Ford    Explorer
# 3    3  vauto_recent_new  1FT7W2A6XKEF37170  2019  Ford     F-250SD
# 4    4  vauto_recent_new  1FTFW1RG2KFB68284  2019  Ford       F-150
#
#                  Trim  Mileage        Date
# 0  Big Horn/Lone Star      NaN  2019-09-27
# 1                 XLT      NaN  2019-08-29
# 2                 XLT     24.0  2019-10-07
# 3                  XL      4.0  2019-09-06
# 4              Raptor     12.0  2019-08-28

# %%
print(used.shape)
used.head()
# Out:
# (2242105, 9)
#    Key             Source                Vin  Year   Make     Model      Trim  \
# 0    0  vauto_recent_used  19XFC2F74GE058406  2016  Honda     Civic        EX
# 1    1  vauto_recent_used  1C4AJWAG5FL553038  2015   Jeep  Wrangler     Sport
# 2    2  vauto_recent_used  1C4PJLCB1GW319991  2016   Jeep  Cherokee  Latitude
# 3    3  vauto_recent_used  1C4PJMAB4EW141130  2014   Jeep  Cherokee     Sport
# 4    4  vauto_recent_used  1C4PJMDX0KD379393  2019   Jeep  Cherokee   Limited
#
#    Mileage        Date
# 0  41218.0  2019-10-05
# 1  53415.0  2019-08-03
# 2  28189.0  2019-10-13
# 3  69167.0  2019-08-15
# 4   3060.0  2019-09-02

# %%
result = pd.concat([new,used])

# %%
result.shape
# Out:
# (3913056, 9)

# %%
result.head()
# Out:
#    Key            Source                Vin  Year  Make       Model  \
# 0    0  vauto_recent_new  1C6SRFFT4KN744751  2019   Ram        1500
# 1    1  vauto_recent_new  1FMJU1HT3KEA63995  2019  Ford  Expedition
# 2    2  vauto_recent_new  1FMSK8DH4LGA36038  2020  Ford    Explorer
# 3    3  vauto_recent_new  1FT7W2A6XKEF37170  2019  Ford     F-250SD
# 4    4  vauto_recent_new  1FTFW1RG2KFB68284  2019  Ford       F-150
#
#                  Trim  Mileage        Date
# 0  Big Horn/Lone Star      NaN  2019-09-27
# 1                 XLT      NaN  2019-08-29
# 2                 XLT     24.0  2019-10-07
# 3                  XL      4.0  2019-09-06
# 4              Raptor     12.0  2019-08-28

# %%
result.describe()
# Out:
#                 Key          Year       Mileage
# count  3.913056e+06  3.913056e+06  3.351192e+06
# mean   9.992427e+05  2.015913e+03  4.513142e+04
# std    5.995228e+05  4.537977e+00  5.497627e+04
# min    0.000000e+00  1.984000e+03  1.000000e+00
# 25%    4.892070e+05  2.014000e+03  1.500000e+01
# 50%    9.784075e+05  2.018000e+03  2.674600e+04
# 75%    1.467618e+06  2.019000e+03  7.213300e+04
# max    2.242343e+06  2.020000e+03  4.000000e+05

# %%
result.to_csv("JZ_merge.csv",index=False)

# %%
see = pd.read_csv('JZ_merge.csv')

# %%
see.head()
# Out:
#    Key            Source                Vin  Year  Make       Model  \
# 0    0  vauto_recent_new  1C6SRFFT4KN744751  2019   Ram        1500
# 1    1  vauto_recent_new  1FMJU1HT3KEA63995  2019  Ford  Expedition
# 2    2  vauto_recent_new  1FMSK8DH4LGA36038  2020  Ford    Explorer
# 3    3  vauto_recent_new  1FT7W2A6XKEF37170  2019  Ford     F-250SD
# 4    4  vauto_recent_new  1FTFW1RG2KFB68284  2019  Ford       F-150
#
#                  Trim  Mileage        Date
# 0  Big Horn/Lone Star      NaN  2019-09-27
# 1                 XLT      NaN  2019-08-29
# 2                 XLT     24.0  2019-10-07
# 3                  XL      4.0  2019-09-06
# 4              Raptor     12.0  2019-08-28
